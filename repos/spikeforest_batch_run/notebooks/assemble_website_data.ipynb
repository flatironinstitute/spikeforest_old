# %% [markdown]
# <a href="https://colab.research.google.com/github/magland/spikeforest_batch_run/blob/master/notebooks/assemble_website_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Assemble website data
#
# This notebook assembles the data for the website.
#
#
# This is the info to Liz on 11/16/18:
#
#
# Here's the data for the website:
# ```
# kb.loadObject(
#     key=dict(
#         target='spikeforest_website_dev',
#         name='studies'
#     )
# )
#
# kb.loadObject(
#     key=dict(
#         target='spikeforest_website_dev',
#         name='recordings'
#     )
# )
#
# kb.loadObject(
#     key=dict(
#         target='spikeforest_website_dev',
#         name='true_units'
#     )
# )
#
# kb.loadObject(
#     key=dict(
#         target='spikeforest_website_dev',
#         name='sorters'
#     )
# )
# ```

# %%
# Only run this cell if you are running this on a hosted runtime that does not have these packages installed
# Consider connecting to a local runtime
# %%capture
# !pip install spikeforest

# %%
from kbucket import client as kb
import spikeforest as sf
import spikeinterface as si
import json
import numpy as np
# Out:
# vdomr: using colab because of VDOMR_MODE environment variable

# %%
## Configure read/write access to kbucket
sf.kbucketConfigRemote(name='spikeforest1-readwrite',ask_password=True)
# Out:
# Enter password: ··········
# Pairio user set to spikeforest. Test succeeded.

# %%
recording_collection_names=[
    'spikeforest_magland_synth_recordings',
    'spikeforest_bionet_recordings',
    'spikeforest_mearec_tetrode_recordings'
]

batch_names=[
    'summarize_recordings_magland_synth','summarize_recordings_bionet','summarize_recordings_mearec_tetrode',
    'ms4_magland_synth','irc_magland_synth','sc_magland_synth_dev4','ks_magland_synth',
    'ms4_bionet','irc_bionet','sc_bionet','ks_bionet',
    'ms4_mearec_tetrode','irc_mearec_tetrode','sc_mearec_tetrode','ks_mearec_tetrode'
]

# %%
## Load the SpikeForest data
SF=sf.SFData()
for rcname in recording_collection_names:
  print(rcname)
  SF.loadRecordings(key=dict(name=rcname))
for bname in batch_names:
  print(bname)
  SF.loadProcessingBatch(key=dict(batch_name=bname,name='job_results'))
# Out:
# spikeforest_magland_synth_recordings
# spikeforest_bionet_recordings
# spikeforest_mearec_tetrode_recordings
# summarize_recordings_magland_synth
# Loaded 0 sorting results and 80 recording summary results
# summarize_recordings_bionet
# Loaded 0 sorting results and 36 recording summary results
# summarize_recordings_mearec_tetrode
# Loaded 0 sorting results and 40 recording summary results
# ms4_magland_synth
# Loaded 80 sorting results and 0 recording summary results
# irc_magland_synth
# Loaded 80 sorting results and 0 recording summary results
# sc_magland_synth_dev4
# Loaded 80 sorting results and 0 recording summary results
# ks_magland_synth
# Loaded 80 sorting results and 0 recording summary results
# ms4_bionet
# Loaded 36 sorting results and 0 recording summary results
# irc_bionet
# Loaded 36 sorting results and 0 recording summary results
# sc_bionet
# Loaded 36 sorting results and 0 recording summary results
# ks_bionet
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/f/8b/f8ba630ebfe54a9138cbd454077e8f739ad7b6cb -> /home/magland/kbucket_cache/f/8b/f8ba630ebfe54a9138cbd454077e8f739ad7b6cb
# Loaded 36 sorting results and 0 recording summary results
# ms4_mearec_tetrode
# Loaded 40 sorting results and 0 recording summary results
# irc_mearec_tetrode
# Loaded 40 sorting results and 0 recording summary results
# sc_mearec_tetrode
# Loaded 40 sorting results and 0 recording summary results
# ks_mearec_tetrode
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/9/9f/99f953cc92bb9aa2b005e3128d6095f4ed327589 -> /home/magland/kbucket_cache/9/9f/99f953cc92bb9aa2b005e3128d6095f4ed327589
# Loaded 40 sorting results and 0 recording summary results

# %%
def min_max_range(a):
  return [min(a),max(a)]

def compute_recording_ranges(study):
  rnames=study.recordingNames()
  summary_objects=[study.recording(rname).getSummaryObject() for rname in rnames]
  recording_dirnames=[study.recording(rname).directory() for rname in rnames]
  
  duration_sec_list=[float(obj['computed_info']['duration_sec']) for obj in summary_objects]
  num_channels_list=[int(obj['computed_info']['num_channels']) for obj in summary_objects]
  samplerate_hz_list=[int(obj['computed_info']['samplerate']) for obj in summary_objects]
  num_true_units_list=[int(len(study.recording(rname).trueUnitsInfo(format='json'))) for rname in rnames]
  file_size_bytes_list=[int(kb.getFileSize(dirname+'/raw.mda')) for dirname in recording_dirnames]
  
  recording_ranges=dict(
      duration_sec=min_max_range(duration_sec_list),
      num_channels=min_max_range(num_channels_list),
      samplerate_hz=min_max_range(samplerate_hz_list),
      file_size_bytes=min_max_range(file_size_bytes_list),
      num_ground_truth_units=min_max_range(num_true_units_list)
  )
  
  return recording_ranges

# %%
## Load the studies
print('Loading studies')
all_studies=[]
studies_by_name=dict()
for sname in SF.studyNames():
  print(sname)
  study=dict(name=sname)
  study['sorters']=[] # initialize
  study['num_recordings']=len(SF.study(sname).recordingNames())
  study['recording_ranges']=compute_recording_ranges(SF.study(sname))
  studies_by_name[sname]=study
  all_studies.append(study)
# Out:
# Loading studies
# magland_synth_noise10_K10_C4
# magland_synth_noise10_K10_C8
# magland_synth_noise10_K20_C4
# magland_synth_noise10_K20_C8
# magland_synth_noise20_K10_C4
# magland_synth_noise20_K10_C8
# magland_synth_noise20_K20_C4
# magland_synth_noise20_K20_C8
# bionet_drift
# bionet_shuffle
# bionet_static
# mearec_tetrode_noise10_K10_C4
# mearec_tetrode_noise10_K20_C4
# mearec_tetrode_noise20_K10_C4
# mearec_tetrode_noise20_K20_C4

# %%
## Load the recordings
print('Loading recordings')
all_recordings=[]
for sname in SF.studyNames():
  SS=SF.study(sname)
  for rname in SS.recordingNames():
    RR=SS.recording(rname)
    recording=RR.getObject()
    all_recordings.append(recording)
# Out:
# Loading recordings

# %%
## Load the units
all_true_units=[]
unit_lookup=dict()
for sname in SF.studyNames():
  SS=SF.study(sname)
  for rname in SS.recordingNames():
    RR=SS.recording(rname)
    true_units_info=RR.trueUnitsInfo(format='json')
    for unit in true_units_info:
      unit['study']=sname
      unit['recording']=rname
      unit['sorting_results']=dict()
      all_true_units.append(unit)
      code=sname+'---'+rname+'---'+str(unit['unit_id'])
      unit_lookup[code]=unit
print('Found {} true units'.format(len(all_true_units)))
# Out:
# Found 4921 true units

# %%
## Load the sorting results
print('Loading sorting results')
count=0
sorters_by_name=dict()
for sname in SF.studyNames():
  SS=SF.study(sname)
  for rname in SS.recordingNames():
    RR=SS.recording(rname)
    for srname in RR.sortingResultNames():
      SR=RR.sortingResult(srname)
      result=SR.getObject()
      if not SR.sorterName() in studies_by_name[sname]['sorters']:
        studies_by_name[sname]['sorters'].append(SR.sorterName())
      obj=SR.comparisonWithTruth(format='json')
      sorter=dict(
          name=result['sorter_name'],
          processor_name=result['sorting_processor_name'],
          processor_version=result['sorting_processor_version'],
          params=result['sorting_params']
      )
      sorters_by_name[SR.sorterName()]=sorter
      for unit_id in obj:
        unit=obj[unit_id]
        code=sname+'---'+rname+'---'+str(unit_id)
        if code in unit_lookup:
          unit_lookup[code]['sorting_results'][SR.sorterName()]=unit
          count=count+1
print('Loaded {} sorted units'.format(count))
# Out:
# Loading sorting results
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/5/7c/57cc82a4287b12a0ba08f883720ef4b702b18b7a -> /home/magland/kbucket_cache/5/7c/57cc82a4287b12a0ba08f883720ef4b702b18b7a
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/7/83/783e9b9cd02dab1aa999560cbc4cdf6f90aed014 -> /home/magland/kbucket_cache/7/83/783e9b9cd02dab1aa999560cbc4cdf6f90aed014
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/d/eb/deb9c57f91f43e07c36be53bed0a39e36497078a -> /home/magland/kbucket_cache/d/eb/deb9c57f91f43e07c36be53bed0a39e36497078a
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/b/38/b387bbd0f073a6285f0c3a57641c3c5ad09cfbae -> /home/magland/kbucket_cache/b/38/b387bbd0f073a6285f0c3a57641c3c5ad09cfbae
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/e/dc/edc8f8722f6ecbf5cc66aaa962606babcc6572de -> /home/magland/kbucket_cache/e/dc/edc8f8722f6ecbf5cc66aaa962606babcc6572de
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/d/8d/d8dd5fcdd0f7f8856d8529cc2efb505c843825c0 -> /home/magland/kbucket_cache/d/8d/d8dd5fcdd0f7f8856d8529cc2efb505c843825c0
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/f/5b/f5bb21c2ae16852d618a91df0151a5ec103edea6 -> /home/magland/kbucket_cache/f/5b/f5bb21c2ae16852d618a91df0151a5ec103edea6
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/6/53/65335b8b8f8c082a812ff67def372e88681dfe57 -> /home/magland/kbucket_cache/6/53/65335b8b8f8c082a812ff67def372e88681dfe57
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/d/31/d3183dfaafaefcb09137c8aa44406bb89ed6ae03 -> /home/magland/kbucket_cache/d/31/d3183dfaafaefcb09137c8aa44406bb89ed6ae03
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/e/0f/e0f76c5be424582aa8a5a4175a7b2d1f9c30159d -> /home/magland/kbucket_cache/e/0f/e0f76c5be424582aa8a5a4175a7b2d1f9c30159d
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/2/f8/2f8f0120a7f1225e45205cac7e4e89faf9ba78fd -> /home/magland/kbucket_cache/2/f8/2f8f0120a7f1225e45205cac7e4e89faf9ba78fd
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/f/7b/f7b06ec37ab20516541fbef0a221f6c186d844d8 -> /home/magland/kbucket_cache/f/7b/f7b06ec37ab20516541fbef0a221f6c186d844d8
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/3/63/363bb6f1fdc954d9aa970a362581f8e3afb632b2 -> /home/magland/kbucket_cache/3/63/363bb6f1fdc954d9aa970a362581f8e3afb632b2
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/b/3a/b3a7d415b1eeca555b34ba0e8119529881de0c63 -> /home/magland/kbucket_cache/b/3a/b3a7d415b1eeca555b34ba0e8119529881de0c63
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/5/44/54413525f42c84dbdf76882aa3ee44861cb924ac -> /home/magland/kbucket_cache/5/44/54413525f42c84dbdf76882aa3ee44861cb924ac
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/1/cc/1cc175033d05f104a3be3fb54730c84d8ce7f35a -> /home/magland/kbucket_cache/1/cc/1cc175033d05f104a3be3fb54730c84d8ce7f35a
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/c/73/c73d873cdddd52233c09141684ae17be3b8f34f3 -> /home/magland/kbucket_cache/c/73/c73d873cdddd52233c09141684ae17be3b8f34f3
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/2/93/2930fea9c7ce2dbebcf7c01a3727f069bda71b60 -> /home/magland/kbucket_cache/2/93/2930fea9c7ce2dbebcf7c01a3727f069bda71b60
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/0/6f/06fea57c63b7b473ff21c9350cb64ebe10644f42 -> /home/magland/kbucket_cache/0/6f/06fea57c63b7b473ff21c9350cb64ebe10644f42
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/9/6d/96dcc7b3debb2f24b2fbdaab7f797ee1d4987f77 -> /home/magland/kbucket_cache/9/6d/96dcc7b3debb2f24b2fbdaab7f797ee1d4987f77
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/d/a7/da782cdd69f23b5d13d7c344e07837acdecd5901 -> /home/magland/kbucket_cache/d/a7/da782cdd69f23b5d13d7c344e07837acdecd5901
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/5/50/550ddac22947908738d7e4e1c1ef9cacfbfe01b4 -> /home/magland/kbucket_cache/5/50/550ddac22947908738d7e4e1c1ef9cacfbfe01b4
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/4/b9/4b991bd586ce40704abb27071496eeb8636ee6f0 -> /home/magland/kbucket_cache/4/b9/4b991bd586ce40704abb27071496eeb8636ee6f0
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/8/1c/81c76684d40d9d751618b1da331d78cd59f83857 -> /home/magland/kbucket_cache/8/1c/81c76684d40d9d751618b1da331d78cd59f83857
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/e/e6/ee68dc01726216a82706c07822e2fb2a897f1441 -> /home/magland/kbucket_cache/e/e6/ee68dc01726216a82706c07822e2fb2a897f1441
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/0/26/026d9e31051e7e5d57c7573f9ac58c6ba41cf955 -> /home/magland/kbucket_cache/0/26/026d9e31051e7e5d57c7573f9ac58c6ba41cf955
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/e/18/e1834439ff93e3321080b063e6b26da805c60bb3 -> /home/magland/kbucket_cache/e/18/e1834439ff93e3321080b063e6b26da805c60bb3
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/e/52/e52d83a5cdbd04f4f45ca2b6a51015b2bbe232a0 -> /home/magland/kbucket_cache/e/52/e52d83a5cdbd04f4f45ca2b6a51015b2bbe232a0
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/3/95/3959406a07584927bf3785803407e4302cc2c9bb -> /home/magland/kbucket_cache/3/95/3959406a07584927bf3785803407e4302cc2c9bb
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/3/8f/38f59df9edd6ca55b347d528816165bd94bf833b -> /home/magland/kbucket_cache/3/8f/38f59df9edd6ca55b347d528816165bd94bf833b
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/9/90/9903a5f810cdafab4677b31c3f4fc6c83efe4ee4 -> /home/magland/kbucket_cache/9/90/9903a5f810cdafab4677b31c3f4fc6c83efe4ee4
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/f/93/f93b340f5cd108d9f086c20929a7050a18ca4a2e -> /home/magland/kbucket_cache/f/93/f93b340f5cd108d9f086c20929a7050a18ca4a2e
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/a/97/a978067830879662e0a2af9139fc4ba0a6a70e6d -> /home/magland/kbucket_cache/a/97/a978067830879662e0a2af9139fc4ba0a6a70e6d
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/5/e0/5e01c3efe5c2fe6b8ae13827c32da1121ba6dfe8 -> /home/magland/kbucket_cache/5/e0/5e01c3efe5c2fe6b8ae13827c32da1121ba6dfe8
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/0/05/005d1e6540d89eb3dafaf2f1c15f2d225db66143 -> /home/magland/kbucket_cache/0/05/005d1e6540d89eb3dafaf2f1c15f2d225db66143
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/f/51/f51840a16343ad8dc12e0a95a670a4096315e57b -> /home/magland/kbucket_cache/f/51/f51840a16343ad8dc12e0a95a670a4096315e57b
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/c/90/c903ba4fd4e4707942a86a84ecc382b368509c2b -> /home/magland/kbucket_cache/c/90/c903ba4fd4e4707942a86a84ecc382b368509c2b
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/e/5a/e5aa4c81b711f61182bef7e799faf3fb0dc79a95 -> /home/magland/kbucket_cache/e/5a/e5aa4c81b711f61182bef7e799faf3fb0dc79a95
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/d/a7/da7c1c893f478c4571b51b7aff37e3b51616c299 -> /home/magland/kbucket_cache/d/a7/da7c1c893f478c4571b51b7aff37e3b51616c299
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/4/37/437bec2c044bc035500d9ff597a4b6ca78ea83ad -> /home/magland/kbucket_cache/4/37/437bec2c044bc035500d9ff597a4b6ca78ea83ad
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/b/71/b71ce2a57bc2f1d2f32f30de65a6b6783e12259e -> /home/magland/kbucket_cache/b/71/b71ce2a57bc2f1d2f32f30de65a6b6783e12259e
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/c/bc/cbc964b59c903bdc3a339e1aab995d8e664364a7 -> /home/magland/kbucket_cache/c/bc/cbc964b59c903bdc3a339e1aab995d8e664364a7
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/d/1c/d1cbfe17b605ee52fc0aa15c20e203533f8e5b84 -> /home/magland/kbucket_cache/d/1c/d1cbfe17b605ee52fc0aa15c20e203533f8e5b84
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/2/65/26596aac1b4f49ecd1c0ceea1f4adc015c5cbc04 -> /home/magland/kbucket_cache/2/65/26596aac1b4f49ecd1c0ceea1f4adc015c5cbc04
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/6/14/614a028a08a692eede426b163b8c2e89a599a659 -> /home/magland/kbucket_cache/6/14/614a028a08a692eede426b163b8c2e89a599a659
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/b/35/b351b342e8556d25a451456339482db45f576c82 -> /home/magland/kbucket_cache/b/35/b351b342e8556d25a451456339482db45f576c82
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/2/13/2137537ac462d42dae5eff7c5802a82acb8d2038 -> /home/magland/kbucket_cache/2/13/2137537ac462d42dae5eff7c5802a82acb8d2038
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/f/25/f256b05aa2013ae8ca1a7f7caa8bc8d24f08834f -> /home/magland/kbucket_cache/f/25/f256b05aa2013ae8ca1a7f7caa8bc8d24f08834f
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/0/be/0be8de2fc818a9e55a09f12285b702fc2688edca -> /home/magland/kbucket_cache/0/be/0be8de2fc818a9e55a09f12285b702fc2688edca
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/3/0e/30e24fa408996f30d75c76b599aa036306c67fa1 -> /home/magland/kbucket_cache/3/0e/30e24fa408996f30d75c76b599aa036306c67fa1
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/3/bb/3bb54184ac2871ebde7fd0f4ada65998f158a9e2 -> /home/magland/kbucket_cache/3/bb/3bb54184ac2871ebde7fd0f4ada65998f158a9e2
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/e/b0/eb0d82913ac833c33eb3199d1fbcefa55957ff33 -> /home/magland/kbucket_cache/e/b0/eb0d82913ac833c33eb3199d1fbcefa55957ff33
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/2/a6/2a6f5441ad573f6b6adb9d5fe543ebfc50156450 -> /home/magland/kbucket_cache/2/a6/2a6f5441ad573f6b6adb9d5fe543ebfc50156450
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/e/3b/e3b2ac76d86cf1418ecefa74ab9f8716caac2ad4 -> /home/magland/kbucket_cache/e/3b/e3b2ac76d86cf1418ecefa74ab9f8716caac2ad4
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/2/86/2864b26aa92204d0efd0c4e1f47a7730ee128e8d -> /home/magland/kbucket_cache/2/86/2864b26aa92204d0efd0c4e1f47a7730ee128e8d
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/5/c5/5c59d87a09997b41dce5655be7eed85ed318096b -> /home/magland/kbucket_cache/5/c5/5c59d87a09997b41dce5655be7eed85ed318096b
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/7/10/7101e31eedc7a49b0ab1d9028a1594148357b773 -> /home/magland/kbucket_cache/7/10/7101e31eedc7a49b0ab1d9028a1594148357b773
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/e/98/e9831e22368a25422a701343324a3e7d9ab20537 -> /home/magland/kbucket_cache/e/98/e9831e22368a25422a701343324a3e7d9ab20537
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/4/b0/4b026b2ff1fa23861eee607ecdd42452a2471b03 -> /home/magland/kbucket_cache/4/b0/4b026b2ff1fa23861eee607ecdd42452a2471b03
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/9/29/929fa7085d55bdcf8598ed8e31b46ec2231e118c -> /home/magland/kbucket_cache/9/29/929fa7085d55bdcf8598ed8e31b46ec2231e118c
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/5/96/596d272cf5b39199bfe5a6bb4e5f927fdc9b5973 -> /home/magland/kbucket_cache/5/96/596d272cf5b39199bfe5a6bb4e5f927fdc9b5973
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/5/91/5916dc76ce17b0002f0319faffba1bdb06519260 -> /home/magland/kbucket_cache/5/91/5916dc76ce17b0002f0319faffba1bdb06519260
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/9/15/9159c1479abba53d16e613e71686f4179e2af933 -> /home/magland/kbucket_cache/9/15/9159c1479abba53d16e613e71686f4179e2af933
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/8/56/856257801feb4c5e58cf9115c78714809bb56554 -> /home/magland/kbucket_cache/8/56/856257801feb4c5e58cf9115c78714809bb56554
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/0/c6/0c6da6c248692615080e4e24a48ef36a43622aed -> /home/magland/kbucket_cache/0/c6/0c6da6c248692615080e4e24a48ef36a43622aed
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/e/b9/eb9463d24a0aa93ba32c5bdbd1e5cce04ddb4f1b -> /home/magland/kbucket_cache/e/b9/eb9463d24a0aa93ba32c5bdbd1e5cce04ddb4f1b
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/e/d5/ed5d1064278477fe7ce815a1ee26d9d359f23f97 -> /home/magland/kbucket_cache/e/d5/ed5d1064278477fe7ce815a1ee26d9d359f23f97
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/e/21/e213ec4c7f7226c15a62efd885d7588102bbbcf0 -> /home/magland/kbucket_cache/e/21/e213ec4c7f7226c15a62efd885d7588102bbbcf0
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/d/42/d42cbc56a95e23170f398a3abf4caafdc7142bb8 -> /home/magland/kbucket_cache/d/42/d42cbc56a95e23170f398a3abf4caafdc7142bb8
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/b/a8/ba8f300059bcf8dac0904292ffaeb57edf48a512 -> /home/magland/kbucket_cache/b/a8/ba8f300059bcf8dac0904292ffaeb57edf48a512
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/f/d9/fd95b19f5f83be80a92b6d9100119417615fbff0 -> /home/magland/kbucket_cache/f/d9/fd95b19f5f83be80a92b6d9100119417615fbff0
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/a/27/a27e01ec4c336060796ff8fdb79189857996d389 -> /home/magland/kbucket_cache/a/27/a27e01ec4c336060796ff8fdb79189857996d389
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/e/bb/ebbefce4d0a2488bdb603c3fb9ad3646447992e0 -> /home/magland/kbucket_cache/e/bb/ebbefce4d0a2488bdb603c3fb9ad3646447992e0
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/2/08/20836d82339cf89c062c81e28f517c0c5f455313 -> /home/magland/kbucket_cache/2/08/20836d82339cf89c062c81e28f517c0c5f455313
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/d/e1/de145aff67888265cbf75f7780b4299d5dafa76e -> /home/magland/kbucket_cache/d/e1/de145aff67888265cbf75f7780b4299d5dafa76e
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/c/13/c13949220cbeb897333af96c83a59d35518be644 -> /home/magland/kbucket_cache/c/13/c13949220cbeb897333af96c83a59d35518be644
# Loaded 8576 sorted units

# %%
target='spikeforest_website_dev'

all_sorters=[]
for sname in sorters_by_name:
  all_sorters.append(sorters_by_name[sname])
print('Found {} sorters'.format(len(all_sorters)))

print('Saving {} studies'.format(len(all_studies)))
kb.saveObject(
    key=dict(
        target=target,
        name='studies'
    ),
    object=dict(
        studies=all_studies
    )
)
    
print('Saving {} recordings'.format(len(all_recordings)))
kb.saveObject(
    key=dict(
        target=target,
        name='recordings'
    ),
    object=dict(
        recordings=all_recordings
    )
)


print('Saving {} true units'.format(len(all_true_units)))
kb.saveObject(
    key=dict(
        target=target,
        name='true_units'
    ),
    object=dict(
        true_units=all_true_units
    )
)

print('Saving {} sorters'.format(len(all_sorters)))
kb.saveObject(
    key=dict(
        target=target,
        name='sorters'
    ),
    object=dict(
        sorters=all_sorters
    )
)
# Out:
# Found 5 sorters
# Saving 15 studies
# Already on server (*)
# Saving 156 recordings
# Already on server.
# Saving 4921 true units
# Already on server (*)
# Saving 5 sorters
# Already on server.

# %%
print('Study:')
obj=kb.loadObject(
    key=dict(
        target='spikeforest_website_dev',
        name='studies'
    )
)
print(json.dumps(obj['studies'][0],indent=4))

print('Recording:')
obj=kb.loadObject(
    key=dict(
        target='spikeforest_website_dev',
        name='recordings'
    )
)
print(json.dumps(obj['recordings'][0],indent=4))


print('Unit:')
obj=kb.loadObject(
    key=dict(
        target='spikeforest_website_dev',
        name='true_units'
    )
)
print(json.dumps(obj['true_units'][0],indent=4))

print('Sorter:')
obj=kb.loadObject(
    key=dict(
        target='spikeforest_website_dev',
        name='sorters'
    )
)
print(json.dumps(obj['sorters'][0],indent=4))
# Out:
# Study:
# {
#     "name": "magland_synth_noise10_K10_C4",
#     "sorters": [
#         "MountainSort4-thr3",
#         "IronClust-tetrode",
#         "SpykingCircus",
#         "KiloSort"
#     ],
#     "num_recordings": 10,
#     "recording_ranges": {
#         "duration_sec": [
#             600.0,
#             600.0
#         ],
#         "num_channels": [
#             4,
#             4
#         ],
#         "samplerate_hz": [
#             30000,
#             30000
#         ],
#         "file_size_bytes": [
#             288000020,
#             288000020
#         ],
#         "num_ground_truth_units": [
#             10,
#             10
#         ]
#     }
# }
# Recording:
# {
#     "name": "001_synth",
#     "study": "magland_synth_noise10_K10_C4",
#     "directory": "kbucket://15734439d8cf/groundtruth/magland_synth/datasets_noise10_K10_C4/001_synth",
#     "description": "One of the recordings in the magland_synth_noise10_K10_C4 study"
# }
# Unit:
# {
#     "unit_id": 1,
#     "snr": 25.396783859187707,
#     "peak_channel": 0,
#     "num_events": 1398,
#     "firing_rate": 2.33,
#     "study": "magland_synth_noise10_K10_C4",
#     "recording": "001_synth",
#     "sorting_results": {
#         "MountainSort4-thr3": {
#             "unit_id": 2,
#             "accuracy": "0.99",
#             "best_unit": 6,
#             "matched_unit": 6,
#             "f_n": "0.00",
#             "f_p": "0.01",
#             "num_matches": 1394
#         },
#         "IronClust-tetrode": {
#             "unit_id": 2,
#             "accuracy": "0.98",
#             "best_unit": 7,
#             "matched_unit": 7,
#             "f_n": "0.00",
#             "f_p": "0.01",
#             "num_matches": 1381
#         },
#         "SpykingCircus": {
#             "Unit ID": 2,
#             "Accuracy": "0.99",
#             "Best unit": 8,
#             "Matched unit": 8,
#             "f.n.": "0.00",
#             "f.p.": "0.01",
#             "# matches": 1384
#         },
#         "KiloSort": {
#             "unit_id": 2,
#             "accuracy": "0.33",
#             "best_unit": 5,
#             "matched_unit": -1,
#             "f_n": "0.67",
#             "f_p": "0.00",
#             "num_matches": 1399
#         }
#     }
# }
# Sorter:
# {
#     "name": "MountainSort4-thr3",
#     "processor_name": "MountainSort4",
#     "processor_version": "4.0.1",
#     "params": {
#         "detect_sign": -1,
#         "adjacency_radius": 100,
#         "detect_threshold": 3
#     }
# }

# %%
print('studies: '+kb.findFile(key=dict(
    target='spikeforest_website_dev',
    name='studies'
),local=False,remote=True))

print('recordings: '+kb.findFile(key=dict(
    target='spikeforest_website_dev',
    name='recordings'
),local=False,remote=True))

print('units: '+kb.findFile(key=dict(
    target='spikeforest_website_dev',
    name='true_units'
),local=False,remote=True))

print('sorters: '+kb.findFile(key=dict(
    target='spikeforest_website_dev',
    name='sorters'
),local=False,remote=True))
# Out:
# studies: http://132.249.245.245:24351/7317cea8265b/download/c/7a/c7afb64466b4bf5aed2dcc8b176d6215ebc15c01
# recordings: http://132.249.245.245:24351/7317cea8265b/download/f/37/f377f635b25dbc1b2a3bad6b9f98f3d3856e7545
# units: http://132.249.245.245:24351/7317cea8265b/download/9/c4/9c4e5906f4ebf28c651bfe45874733c269ed7b5e
# sorters: http://132.249.245.245:24351/7317cea8265b/download/3/e8/3e8e627d69c194eb3b3fa4bad3aec5b7adba8187

# %%
## This was the old method

all_sorting_results=[]
all_summarize_recording_results=[]
for bname in batch_names:
  print('Loading '+bname)
  obj=kb.loadObject(key=dict(batch_name=bname,name='job_results'))
  job_results=obj['job_results']
  for res in job_results:
    if res['job']['command']=='sort_recording':
      all_sorting_results.append(res)
    elif res['job']['command']=='summarize_recording':
      if 'true_units_info' in res['result']:
        all_summarize_recording_results.append(res)
      else:
        print('WARNING: no field, true_units_info, skipping.')
        display(res)

import json
def load_json(fname):
  fname=kb.realizeFile(fname)
  with open(fname) as f:
    return json.load(f)

def use_study(name):
  if name.startswith('magland'):
    return True
  if name.startswith('bionet'):
    return True
  return False

## Load the studies
print('Loading studies')
all_studies=[]
studies_by_name=dict()
obj=kb.loadObject(key=dict(name='spikeforest_recordings'))
studies=obj['studies']
for study in studies:
  study['sorters']=[] # initialize
  studies_by_name[study['name']]=study
  if use_study(study['name']):
    all_studies.append(study)

## Load the recordings
print('Loading recordings')
all_recordings=[]
for res in all_summarize_recording_results:
  recording=res['result']
  study=recording['study']
  if use_study(recording['study']):
    all_recordings.append(recording)
    
## Load the units
all_true_units=[]
unit_lookup=dict()
print('Loading summarize recording results')
for res in all_summarize_recording_results:
  study=res['job']['recording']['study']
  recording=res['job']['recording']['name']
  if use_study(study):
    obj=load_json(res['result']['true_units_info'])
    for unit in obj:
      unit['study']=study
      unit['recording']=recording
      unit['sorting_results']=dict()
      all_true_units.append(unit)
      code=study+'---'+recording+'---'+str(unit['unit_id'])
      unit_lookup[code]=unit
  #res['result']['true_units_info_data']=obj
print('Found {} true units'.format(len(all_true_units)))

## Load the sorting results
print('Loading sorting results')
count=0
sorters_by_name=dict()
for res in all_sorting_results:
  study=res['job']['recording']['study']
  recording=res['job']['recording']['name']
  sorter=res['job']['sorter']['name']
  if not sorter in studies_by_name[study]['sorters']:
    studies_by_name[study]['sorters'].append(sorter)
  if use_study(study):
    obj=load_json(res['result']['comparison_with_truth']['json'])
    sorters_by_name[sorter]=res['job']['sorter']
    for unit_id in obj:
      unit=obj[unit_id]
      code=study+'---'+recording+'---'+str(unit_id)
      if code in unit_lookup:
        unit_lookup[code]['sorting_results'][sorter]=unit
        count=count+1
print('Loaded {} sorted units'.format(count))

all_sorters=[]
for sname in sorters_by_name:
  all_sorters.append(sorters_by_name[sname])
print('Found {} sorters'.format(len(all_sorters)))

print('Saving {} studies'.format(len(all_studies)))
kb.saveObject(
    key=dict(
        target='spikeforest_website',
        name='studies'
    ),
    object=dict(
        studies=all_studies
    )
)
    
print('Saving {} recordings'.format(len(all_recordings)))
kb.saveObject(
    key=dict(
        target='spikeforest_website',
        name='recordings'
    ),
    object=dict(
        recordings=all_recordings
    )
)


print('Saving units')
kb.saveObject(
    key=dict(
        target='spikeforest_website',
        name='true_units'
    ),
    object=dict(
        true_units=all_true_units
    )
)

print('Saving sorters')
kb.saveObject(
    key=dict(
        target='spikeforest_website',
        name='sorters'
    ),
    object=dict(
        sorters=all_sorters
    )
)

  
#print('Loading summarize recording results')
#for res in all_summarize_recording_results:
#  obj=load_json(res['result']['true_units_info'])
#  res['result']['true_units_info_data']=obj
# Out:
# Loading studies
# Loading recordings
# Loading summarize recording results
# Found 26688 true units
# Loading sorting results
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/a/65/a65d172d96d74c8b92e9b4125152eb0bee2296d2 -> /home/magland/kbucket_cache/a/65/a65d172d96d74c8b92e9b4125152eb0bee2296d2
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/9/7f/97fe8157e6c38915aadf5b9013952a4b0191a366 -> /home/magland/kbucket_cache/9/7f/97fe8157e6c38915aadf5b9013952a4b0191a366
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/f/37/f375280367ae2e171790c6be34fcdd0cf9a84e17 -> /home/magland/kbucket_cache/f/37/f375280367ae2e171790c6be34fcdd0cf9a84e17
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/3/1a/31ad16e4f4ed9d0d1e14671ca67e38796d146216 -> /home/magland/kbucket_cache/3/1a/31ad16e4f4ed9d0d1e14671ca67e38796d146216
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/5/29/529ed0ab48032a8c16777e8a50bf4f7c0f3f9ea8 -> /home/magland/kbucket_cache/5/29/529ed0ab48032a8c16777e8a50bf4f7c0f3f9ea8
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/9/8f/98fc58d40dfed736293e61c8aae6e14c35f3c525 -> /home/magland/kbucket_cache/9/8f/98fc58d40dfed736293e61c8aae6e14c35f3c525
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/e/99/e9979b460d686f5c3c5b2b9d339aad9af6f86f32 -> /home/magland/kbucket_cache/e/99/e9979b460d686f5c3c5b2b9d339aad9af6f86f32
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/2/6f/26f4fe6cd0b8a73d6629e69216211ed362f0f3ee -> /home/magland/kbucket_cache/2/6f/26f4fe6cd0b8a73d6629e69216211ed362f0f3ee
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/c/cc/ccc7cf51170d7f0aa77e146875d5298482f51796 -> /home/magland/kbucket_cache/c/cc/ccc7cf51170d7f0aa77e146875d5298482f51796
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/c/e6/ce65dc11fad0f089e675c7ecc1594c7c9f5cf5ca -> /home/magland/kbucket_cache/c/e6/ce65dc11fad0f089e675c7ecc1594c7c9f5cf5ca
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/a/60/a6057de35308751adeeff1655fc49f60865f2417 -> /home/magland/kbucket_cache/a/60/a6057de35308751adeeff1655fc49f60865f2417
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/8/a9/8a9129c0370713d5d244c28a67bdea7bc8d11856 -> /home/magland/kbucket_cache/8/a9/8a9129c0370713d5d244c28a67bdea7bc8d11856
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/d/6d/d6d94a9a6edb6650cbefe911d3ca76d1d53a6242 -> /home/magland/kbucket_cache/d/6d/d6d94a9a6edb6650cbefe911d3ca76d1d53a6242
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/1/df/1df64200ffdd655c6cef5e7cad66ea627eb49b49 -> /home/magland/kbucket_cache/1/df/1df64200ffdd655c6cef5e7cad66ea627eb49b49
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/3/67/367fe176857c6685333caae787ead276432ab953 -> /home/magland/kbucket_cache/3/67/367fe176857c6685333caae787ead276432ab953
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/8/eb/8eb53443c370f693384245547154908092fd63fc -> /home/magland/kbucket_cache/8/eb/8eb53443c370f693384245547154908092fd63fc
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/7/c2/7c2dfe92618918e39e3e29e03d29c35d6061691e -> /home/magland/kbucket_cache/7/c2/7c2dfe92618918e39e3e29e03d29c35d6061691e
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/2/ac/2ac848c9b681cdd09307b0e9d6ab6e93faef2707 -> /home/magland/kbucket_cache/2/ac/2ac848c9b681cdd09307b0e9d6ab6e93faef2707
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/3/a9/3a95e5726c85d59d2a5fec279b2423961f507447 -> /home/magland/kbucket_cache/3/a9/3a95e5726c85d59d2a5fec279b2423961f507447
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/c/27/c279cad8ee4696f67f792b54ca2d691eae59620e -> /home/magland/kbucket_cache/c/27/c279cad8ee4696f67f792b54ca2d691eae59620e
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/b/e3/be35a4298af948859c28edc02902ee2ac11ca151 -> /home/magland/kbucket_cache/b/e3/be35a4298af948859c28edc02902ee2ac11ca151
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/f/68/f68d1cab85328230db09bf72b7ae32de1c4dfad5 -> /home/magland/kbucket_cache/f/68/f68d1cab85328230db09bf72b7ae32de1c4dfad5
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/5/48/5484af2e73bbfc923d675568a6864236ff8b4147 -> /home/magland/kbucket_cache/5/48/5484af2e73bbfc923d675568a6864236ff8b4147
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/f/1d/f1d1102214ad04693dd4271e606422cc15428455 -> /home/magland/kbucket_cache/f/1d/f1d1102214ad04693dd4271e606422cc15428455
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/0/dd/0ddd49c0098eea7243a28c3f0cea1c45d1dac0a9 -> /home/magland/kbucket_cache/0/dd/0ddd49c0098eea7243a28c3f0cea1c45d1dac0a9
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/5/27/5272273c5b91f04a77f99ed169788bc58c793072 -> /home/magland/kbucket_cache/5/27/5272273c5b91f04a77f99ed169788bc58c793072
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/f/54/f54cc03b53ee87ec49c5af9b042c2ef6a56fa7cb -> /home/magland/kbucket_cache/f/54/f54cc03b53ee87ec49c5af9b042c2ef6a56fa7cb
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/9/81/98135f2f2429a07e383f66f4f731e3a68d8924d7 -> /home/magland/kbucket_cache/9/81/98135f2f2429a07e383f66f4f731e3a68d8924d7
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/2/86/2862185579d13dfcfab3210e9f941dcde5898749 -> /home/magland/kbucket_cache/2/86/2862185579d13dfcfab3210e9f941dcde5898749
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/3/ab/3ab576a91577a706e5cf19b794123193f1ea515f -> /home/magland/kbucket_cache/3/ab/3ab576a91577a706e5cf19b794123193f1ea515f
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/c/b4/cb4fa882d28dadd78f656334da5f85ec92be547c -> /home/magland/kbucket_cache/c/b4/cb4fa882d28dadd78f656334da5f85ec92be547c
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/c/d7/cd746106f8c2719719a90f967ed1d69cf247d8a2 -> /home/magland/kbucket_cache/c/d7/cd746106f8c2719719a90f967ed1d69cf247d8a2
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/7/2a/72a053e240a0429f3f9047ad87e4b05baebab824 -> /home/magland/kbucket_cache/7/2a/72a053e240a0429f3f9047ad87e4b05baebab824
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/2/1b/21bccb40e388e9d49c6d95100c8951139cb5e4be -> /home/magland/kbucket_cache/2/1b/21bccb40e388e9d49c6d95100c8951139cb5e4be
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/5/c9/5c9c5fbd5f5c48c2b4709214c8c71fc90a9ea6c2 -> /home/magland/kbucket_cache/5/c9/5c9c5fbd5f5c48c2b4709214c8c71fc90a9ea6c2
# Downloading file --- (0.0 MB): http://132.249.245.245:24351/7317cea8265b/download/f/79/f79ac6448c3fd3e6e9010fe61cbfdd5fb25bb01f -> /home/magland/kbucket_cache/f/79/f79ac6448c3fd3e6e9010fe61cbfdd5fb25bb01f
# Loaded 12615 sorted units
# Found 4 sorters
# Saving 11 studies
# Saving 116 recordings
# Already on server.
# Saving units
# Saving sorters
# Already on server.
