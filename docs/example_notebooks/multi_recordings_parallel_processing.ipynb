# %%
# This example runs multiple sorters in parallel using a local computer
# Created by James Jun on Mar 27, 2019

# prerequisits
# $ pip install ml_ms4alg
# $ conda install -c conda-forge ipywidgets
# $ jupyter labextension install @jupyter-widgets/jupyterlab-manager

# please ignore the warning when running MountainSort4
#   RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import spikeforest_analysis as sa
from spikeforest import spikeextractors as se
import os, shutil, datetime, json, numpy as np, pandas as pd, json, datetime
import sfdata as sf
from spikesorters import IronClust, MountainSort4, KiloSort, KiloSort2
from spikeforest import spiketoolkit as st
from spikeforest import spikewidgets as sw
import ipywidgets as widgets
from spikeforest_analysis.compare_sortings_with_truth import GenSortingComparisonTable
from spikeforest_analysis.compute_units_info import ComputeUnitsInfo
from matplotlib import pyplot as plt
import mlprocessors as mlpr
from mlprocessors import LocalComputeResource

# %%
# Define sorters
# run `createJob` instead of `execute` for delayed execution

f_force_run = True
adjacency_radius = 100

def irc_static(recpath, firings_out):
    return IronClust.createJob(
            recording_dir=recpath,
            firings_out=firings_out,
            detect_sign=-1,
            adjacency_radius=adjacency_radius,
            prm_template_name='static',
            _force_run=f_force_run)

def irc_drift(recpath, firings_out):
    return IronClust.createJob(
            recording_dir=recpath,
            firings_out=firings_out,
            detect_sign=-1,
            adjacency_radius=adjacency_radius,
            prm_template_name='drift',
            _force_run=f_force_run)

def ms4(recpath, firings_out):
    return MountainSort4.createJob(
            recording_dir=recpath,
            firings_out=firings_out,
            detect_sign=-1,
            adjacency_radius=adjacency_radius,
            _force_run=f_force_run)

def ksort(recpath, firings_out):
    return KiloSort.createJob(
            recording_dir=recpath,
            firings_out=firings_out,
            detect_sign=-1,
            adjacency_radius=adjacency_radius,
            _force_run=f_force_run)

def ksort2(recpath, firings_out):
    return KiloSort2.createJob(
            recording_dir=recpath,
            firings_out=firings_out,
            detect_sign=-1,
            adjacency_radius=adjacency_radius,
            _force_run=f_force_run)

#D_sorters = dict(KiloSort=ksort, IronClust_static=irc, MountainSort4=ms4, KiloSort2=ksort2, IronClust_drift=irc_drift)
D_sorters = dict(KiloSort=ksort, IronClust_static=irc_static, MountainSort4=ms4)

# %%
# select a data source and sorter
# you may change the data source index and sorter index
LS_sorter = list(D_sorters.keys())
LS_sorter.insert(0,'all')

widget1 = widgets.Dropdown(
    options=LS_sorter, index=0, description='Spike sorters')
display(widget1)

LS_datasource = ['generate locally', 'download']
widget2 = widgets.Dropdown(
    options = LS_datasource, index=0, description='Data source')
display(widget2)
# Out:
# Dropdown(description='Spike sorters', options=('all', 'KiloSort', 'IronClust_static', 'MountainSort4'), value=…
# Dropdown(description='Data source', options=('generate locally', 'download'), value='generate locally')

# %%
# create a parameters dictionary
D_params = dict(
    datasource = LS_datasource[widget2.index],
    path_in = 'recordings/example1',
    path_out = 'sortings/example1',
    num_repeat = 4
    )

S_sorter = LS_sorter[widget1.index]
if S_sorter == 'all':
    D_params['sorter'] = LS_sorter[1:]
    
else:
    D_params['sorter'] = [S_sorter]

# %%
# get recording
path_in = D_params['path_in']
# delete previous recording
#  os.path.exists(recpath): shutil.rmtree(recpath)
# delete previous output and make save
path_in_true = os.path.join(path_in, 'firings_true.mda')
path_in_json = os.path.join(path_in, 'units_info.json')

if D_params['datasource'] == 'generate locally':
    print(path_in_true)
    if not os.path.exists(path_in_true):
        # generate recording
        rx, sx_true = se.example_datasets.toy_example1(
            duration=600, num_channels=4, samplerate=30000, K=10)
        print('Generated recording in ' + path_in)
    else:
        rx = se.MdaRecordingExtractor(path_in)
        sx_true = se.MdaSortingExtractor(path_in_true)
        print('Using cached recording in ' + path_in)
else:
    # download recording
    #kpath = 'kbucket://15734439d8cf/groundtruth/magland_synth/datasets_noise10_K10_C4/001_synth'
    #kpath = '/mnt/home/jjun/ceph/groundtruth/hybrid_drift/rec_32c_600s_11'
    kpath = '/mnt/home/jjun/ceph/groundtruth/hybrid_drift/rec_64c_1200s_11'
    rx = se.MdaRecordingExtractor(kpath, download=True)
    sx_true = se.MdaSortingExtractor(kpath + '/firings_true.mda')   
    
if not os.path.exists(path_in): 
    os.makedirs(path_in)
    se.MdaRecordingExtractor.writeRecording(recording=rx, save_path=path_in)
    se.MdaSortingExtractor.writeSorting(
        sorting=sx_true, save_path=path_in_true)
        
# summarize recording
if not os.path.exists(path_in_json):
    ComputeUnitsInfo.execute(
        recording_dir = path_in,
        firings = path_in_true,
        json_out = path_in_json,
        )
with open(path_in_json) as f:
    snr_json = json.load(f)
    unit_snrs = [x['snr'] for x in snr_json]
    unit_ids = [x['unit_id'] for x in snr_json]
    sx_true.setUnitsProperty(property_name='snr', 
         values=unit_snrs, unit_ids=unit_ids)
# Out:
# recordings/example1/firings_true.mda
# Generated recording in recordings/example1
# Preparing 1 local file inputs
# Preparing 1 local directory inputs
# Computing sha1 of recordings/example1/raw.mda
# Computing output signatures...
# .
# Job: ComputeUnitsInfo (version: 0.1.8)
# Timestamp: 2019-03-27 21:16:11
# Running processor directly...
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_ComputeUnitsInfoaks0mj2w/json_out.json -> /home/jjun/src/spikeforest/docs/example_notebooks/recordings/example1/units_info.json

# %%
t1 = datetime.datetime.now()

# Schedule spike sorting tasks
path_in = D_params['path_in']
path_out = D_params['path_out']
nJobs = D_params['num_repeat']
L_jobs_sorting = list()
for S_sorter1 in D_params['sorter']:
    for iJob in range(nJobs):
        path_out1 = '{}_{}'.format(os.path.join(path_out, S_sorter1), iJob)
        if not os.path.exists(path_out1): 
            os.makedirs(path_out1)  
        path_out_firings1 = os.path.join(path_out1, 'firings_out.mda')
        if not os.path.exists(path_out_firings1):
            print('Running '+ S_sorter1 + ' in notebook.')
            L_jobs_sorting.append(D_sorters[S_sorter1](path_in, path_out_firings1))   
        
# Run sorting jobs
with LocalComputeResource(num_parallel=4) as compute_resource:
    mlpr.executeBatch(jobs=L_jobs_sorting, compute_resource=compute_resource)
        
# Collect results and run validation
L_jobs_comparison = list()
for S_sorter1 in D_params['sorter']:
    for iJob in range(nJobs):
        path_out1 = '{}_{}'.format(os.path.join(path_out, S_sorter1), iJob)
        path_out_firings1 = os.path.join(path_out1, 'firings_out.mda')
        sx1 = se.MdaSortingExtractor(path_out_firings1)
        print('Loaded '+ S_sorter1 + ' from ' + path_out_firings1)
    
        # validation           
        path_out_json1 = os.path.join(path_out1, 'sorting_comparison.json')
        if not os.path.exists(path_out_json1):
            print('Computing comparison...')
            job1 = GenSortingComparisonTable.createJob(
                firings = path_out_firings1,
                units_true = None,
                firings_true = os.path.join(path_in, 'firings_true.mda'),
                json_out = path_out_json1,
                html_out = os.path.join(path_out1, 'sorting_comparison.html'),
                )
            L_jobs_comparison.append(job1)

# Run comparison jobs
with LocalComputeResource(num_parallel=4) as compute_resource:
    mlpr.executeBatch(jobs=L_jobs_comparison, compute_resource=compute_resource)
# Out:
# Running KiloSort in notebook.
# Preparing 1 local directory inputs
# Computing output signatures...
# .
# Running KiloSort in notebook.
# Preparing 1 local directory inputs
# Computing output signatures...
# .
# Running KiloSort in notebook.
# Preparing 1 local directory inputs
# Computing output signatures...
# .
# Running KiloSort in notebook.
# Preparing 1 local directory inputs
# Computing output signatures...
# .
# Running IronClust_static in notebook.
# Preparing 1 local directory inputs
# Computing output signatures...
# .
# Running IronClust_static in notebook.
# Preparing 1 local directory inputs
# Computing output signatures...
# .
# Running IronClust_static in notebook.
# Preparing 1 local directory inputs
# Computing output signatures...
# .
# Running IronClust_static in notebook.
# Preparing 1 local directory inputs
# Computing output signatures...
# .
# Running MountainSort4 in notebook.
# Preparing 1 local directory inputs
# Computing output signatures...
# .
# Running MountainSort4 in notebook.
# Preparing 1 local directory inputs
# Computing output signatures...
# .
# Running MountainSort4 in notebook.
# Preparing 1 local directory inputs
# Computing output signatures...
# .
# Running MountainSort4 in notebook.
# Preparing 1 local directory inputs
# Computing output signatures...
# .
# Checking for cached results prior to sending to compute resource...
# MOUNTAIN CONFIG: local database; local sha-1 cache
# registering compute resource:  local_resource_qOTgEB
# local_resource_qOTgEB: Starting compute resource: local_resource_qOTgEB
# local_resource_qOTgEB: No batches pending.
# Ensuring files are available on remote server...
# MOUNTAIN CONFIG: local database; local sha-1 cache
# Waiting for batch to start on compute resource: local_resource_qOTgEB
# local_resource_qOTgEB: Starting batch: batch_1553736284.8523128_mdQaER
# local_resource_qOTgEB: Loading batch: batch_1553736284.8523128_mdQaER
# local_resource_qOTgEB: Starting batch: batch_1553736284.8523128_mdQaER
# Making sure files are available on local computer...
# Realizing sha1://aac3ff05a8bf05ef1515e29799045a5e645ecc4c/object.json...
# Realizing sha1://fa1e819de2d73fb439c2a7c5668bf97374491c6b/object.json...
# Realizing sha1://8f3ad58d25364c21c3d6573953d2d2cc98fa6c48/object.json...
# Job: KiloSort (version: 0.2.0)
# Timestamp: 2019-03-27 21:24:45
# Job: KiloSort (version: 0.2.0)
# Timestamp: 2019-03-27 21:24:45
# RUNNING SHELL SCRIPT: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_KiloSortfutv8p5o/run.sh
# Job: KiloSort (version: 0.2.0)
# Timestamp: 2019-03-27 21:24:45
# RUNNING SHELL SCRIPT: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_KiloSortig1c96sq/run.sh
# RUNNING SHELL SCRIPT: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_KiloSorto0dba8ev/run.sh
# Job: KiloSort (version: 0.2.0)
# Timestamp: 2019-03-27 21:24:45
# RUNNING SHELL SCRIPT: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_KiloSort030qoi4c/run.sh
# BATCH  running: 3 running, 0 finished, 0 errors -- 12 total jobs
# BATCH  running: 4 running, 0 finished, 0 errors -- 12 total jobs
# >> Running processor (class=KiloSort) ...
# >> Reading timeseries header...
# >> Num. channels = 4, Num. timepoints = 18000000, duration = 10.0 minutes
# >> Creating argfile.txt file...
# >> Running kilosort...
# >> matlab -nosplash -nodisplay -r "addpath('/mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_KiloSortig1c96sq/processor_source');  p_kilosort('/mnt/home/jjun/src/KiloSort', '/mnt/home/jjun/src/ironclust', '/tmp/kilosort-tmp-RDEQMJQIJY', '/tmp/kilosort-tmp-RDEQMJQIJY/kilosort_dataset/raw.mda', '/tmp/kilosort-tmp-RDEQMJQIJY/kilosort_dataset/geom.csv', '/tmp/kilosort-tmp-RDEQMJQIJY/firings.mda', '/tmp/kilosort-tmp-RDEQMJQIJY/kilosort_dataset/argfile.txt'); quit;"
# >>
# >>
# >>                             < M A T L A B (R) >
# >>
# >>                   Copyright 1984-2018 The MathWorks, Inc.
# >>
# >>                    R2018b (9.5.0.944444) 64-bit (glnxa64)
# >>
# >>                               August 28, 2018
# >>
# >>
# >>
# >>
# >>
# >> To get started, type doc.
# >>
# >> For product information, visit www.mathworks.com.
# >>
# >>
# >>
# >>
# >>
# >> 	Non-Degree Granting Education License -- for use at non-degree granting, nonprofit,
# >>
# >> 	educational organizations only.  Not for government, commercial, or other organizational use.
# >>
# >>
# >>
# >> Running kilosort on /tmp/kilosort-tmp-RDEQMJQIJY/kilosort_dataset/raw.mda
# >>
# >> Time   1s. Loading raw data...
# >>
# >> Time  24s. Channel-whitening filters computed.
# >>
# >> Time  24s. Loading raw data and applying filters...
# >>
# >> Time 33.04. Whitened data written to disk...
# >>
# >> Time 33.04. Preprocessing complete!
# >>
# >> Time  35s. Optimizing templates ...
# >>
# >> Time 34.69, batch 1/828, mu 5.07, neg-err 23081.501953, NTOT 86, n100 0, n200 0, n300 0, n400 0
# >>
# >Time 34.91, batch 21/828, mu 5.07, neg-err 27366.053571, NTOT 1997, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 35.06, batch 41/828, mu 5.07, neg-err 28643.265244, NTOT 3980, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 35.22, batch 61/828, mu 5.07, neg-err 28119.731541, NTOT 5843, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 35.38, batch 81/828, mu 5.07, neg-err 28382.706055, NTOT 7807, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 35.54, batch 101/828, mu 5.07, neg-err 28452.341130, NTOT 9709, n100 0, n200 0, n300 0, n400 0
# >>
# >Time 35.69, batch 121/828, mu 5.07, neg-err 28583.929324, NTOT 11690, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 38.58, batch 141/828, mu 7.81, neg-err 28695.193664, NTOT 13807, n100 17, n200 17, n300 17, n400 17
# >>
# >>Time 38.70, batch 161/828, mu 7.81, neg-err 29311.787230, NTOT 13722, n100 14, n200 14, n300 14, n400 14
# >>
# >>Time 38.82, batch 181/828, mu 7.81, neg-err 29987.912201, NTOT 13666, n100 12, n200 12, n300 12, n400 12
# >>
# >>Time 38.94, batch 201/828, mu 7.81, neg-err 30608.908097, NTOT 13582, n100 9, n200 9, n300 9, n400 9
# >>
# >>Time 39.06, batch 221/828, mu 7.81, neg-err 31259.469281, NTOT 13524, n100 7, n200 7, n300 7, n400 7
# >>
# >>Time 39.20, batch 241/828, mu 7.81, neg-err 31945.455977, NTOT 13441, n100 4, n200 4, n300 4, n400 4
# >>
# >>Time 39.33, batch 261/828, mu 7.81, neg-err 32583.183558, NTOT 13386, n100 2, n200 2, n300 2, n400 2
# >>
# >>Time 39.68, batch 281/828, mu 8.44, neg-err 33190.534229, NTOT 13738, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 39.81, batch 301/828, mu 8.44, neg-err 33489.654134, NTOT 13666, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 39.94, batch 321/828, mu 8.44, neg-err 33839.309719, NTOT 13618, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 40.07, batch 341/828, mu 8.44, neg-err 34155.005583, NTOT 13546, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 40.20, batch 361/828, mu 8.44, neg-err 34494.586978, NTOT 13498, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 40.46, batch 381/828, mu 8.44, neg-err 34864.990383, NTOT 13425, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 40.75, batch 401/828, mu 8.44, neg-err 35200.694782, NTOT 13377, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 41.16, batch 421/828, mu 8.61, neg-err 35420.404757, NTOT 13745, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 41.54, batch 441/828, mu 8.61, neg-err 35436.325146, NTOT 13692, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 41.93, batch 461/828, mu 8.61, neg-err 35455.930699, NTOT 13614, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 42.31, batch 481/828, mu 8.61, neg-err 35474.049387, NTOT 13562, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 42.59, batch 501/828, mu 8.61, neg-err 35493.164990, NTOT 13484, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 42.91, batch 521/828, mu 8.61, neg-err 35514.833482, NTOT 13432, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 43.30, batch 541/828, mu 8.61, neg-err 35534.211567, NTOT 13354, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 43.79, batch 561/828, mu 7.22, neg-err 35542.722961, NTOT 13696, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 44.17, batch 581/828, mu 7.22, neg-err 35539.202113, NTOT 13650, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 44.56, batch 601/828, mu 7.22, neg-err 35535.486180, NTOT 13581, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 44.95, batch 621/828, mu 7.22, neg-err 35533.133655, NTOT 13535, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 45.29, batch 641/828, mu 7.22, neg-err 35530.512349, NTOT 13466, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 45.60, batch 661/828, mu 7.22, neg-err 35526.666914, NTOT 13420, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 45.99, batch 681/828, mu 7.22, neg-err 35523.401091, NTOT 13352, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 46.47, batch 701/828, mu 8.11, neg-err 35520.560186, NTOT 13745, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 46.85, batch 721/828, mu 8.11, neg-err 35521.291334, NTOT 13667, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 47.23, batch 741/828, mu 8.11, neg-err 35522.091875, NTOT 13615, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 47.62, batch 761/828, mu 8.11, neg-err 35522.478763, NTOT 13537, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 47.97, batch 781/828, mu 8.11, neg-err 35522.983858, NTOT 13484, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 48.28, batch 801/828, mu 8.11, neg-err 35524.723371, NTOT 13406, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 48.68, batch 821/828, mu 8.11, neg-err 35524.797547, NTOT 13353, n100 0, n200 0, n300 0, n400 0
# >>
# >> Time  49s. Running the final template matching pass...
# >>
# >> Time 49.32, batch 1/138,  NTOT 114
# >>
# >>Time 60.29, batch 101/138,  NTOT 10329
# >>
# >>
# >>
# >> 	took 64.2s
# >>
# >> Clustering result wrote to /tmp/kilosort-tmp-RDEQMJQIJY/firings.mda
# >>
# ========== KiloSort exited with code 0 after 80.03701043128967 sec
# ================================================================================
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_KiloSort8zp4e8kp/firings_out.mda -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/KiloSort_3/firings_out.mda
# Saving result object...
# Job: IronClust (version: 0.2.1)
# Timestamp: 2019-03-27 21:26:06
# RUNNING SHELL SCRIPT: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_IronClust8t5hxhsr/run.sh
# Uploading result for job 3
# >> Running processor (class=KiloSort) ...
# >> Reading timeseries header...
# >> Num. channels = 4, Num. timepoints = 18000000, duration = 10.0 minutes
# >> Creating argfile.txt file...
# >> Running kilosort...
# >> matlab -nosplash -nodisplay -r "addpath('/mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_KiloSorto0dba8ev/processor_source');  p_kilosort('/mnt/home/jjun/src/KiloSort', '/mnt/home/jjun/src/ironclust', '/tmp/kilosort-tmp-JXRCSQTNYZ', '/tmp/kilosort-tmp-JXRCSQTNYZ/kilosort_dataset/raw.mda', '/tmp/kilosort-tmp-JXRCSQTNYZ/kilosort_dataset/geom.csv', '/tmp/kilosort-tmp-JXRCSQTNYZ/firings.mda', '/tmp/kilosort-tmp-JXRCSQTNYZ/kilosort_dataset/argfile.txt'); quit;"
# >>
# >>
# >>                             < M A T L A B (R) >
# >>
# >>                   Copyright 1984-2018 The MathWorks, Inc.
# >>
# >>                    R2018b (9.5.0.944444) 64-bit (glnxa64)
# >>
# >>                               August 28, 2018
# >>
# >>
# >>
# >>
# >>
# >> To get started, type doc.
# >>
# >> For product information, visit www.mathworks.com.
# >>
# >>
# >>
# >>
# >>
# >> 	Non-Degree Granting Education License -- for use at non-degree granting, nonprofit,
# >>
# >> 	educational organizations only.  Not for government, commercial, or other organizational use.
# >>
# >>
# >>
# >> Running kilosort on /tmp/kilosort-tmp-JXRCSQTNYZ/kilosort_dataset/raw.mda
# >>
# >> Time   1s. Loading raw data...
# >>
# >> Time  25s. Channel-whitening filters computed.
# >>
# >> Time  25s. Loading raw data and applying filters...
# >>
# >> Time 34.40. Whitened data written to disk...
# >>
# >> Time 34.40. Preprocessing complete!
# >>
# >> Time  36s. Optimizing templates ...
# >>
# >> Time 35.85, batch 1/828, mu 5.07, neg-err 23081.503906, NTOT 86, n100 0, n200 0, n300 0, n400 0
# >>
# >Time 36.07, batch 21/828, mu 5.07, neg-err 27366.053199, NTOT 1997, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 36.26, batch 41/828, mu 5.07, neg-err 28643.264910, NTOT 3980, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 36.46, batch 61/828, mu 5.07, neg-err 28119.731317, NTOT 5843, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 36.67, batch 81/828, mu 5.07, neg-err 28382.705862, NTOT 7807, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 36.88, batch 101/828, mu 5.07, neg-err 28452.340994, NTOT 9709, n100 0, n200 0, n300 0, n400 0
# >>
# >Time 37.09, batch 121/828, mu 5.07, neg-err 28583.929244, NTOT 11690, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 39.82, batch 141/828, mu 7.81, neg-err 28695.233618, NTOT 13807, n100 17, n200 17, n300 17, n400 17
# >>
# >>Time 40.11, batch 161/828, mu 7.81, neg-err 29311.890434, NTOT 13722, n100 14, n200 14, n300 14, n400 14
# >>
# >>Time 40.40, batch 181/828, mu 7.81, neg-err 29988.196551, NTOT 13666, n100 12, n200 12, n300 12, n400 12
# >>
# >>Time 40.64, batch 201/828, mu 7.81, neg-err 30609.296061, NTOT 13582, n100 9, n200 9, n300 9, n400 9
# >>
# >>Time 41.01, batch 221/828, mu 7.81, neg-err 31260.048354, NTOT 13524, n100 7, n200 7, n300 7, n400 7
# >>
# >>Time 41.39, batch 241/828, mu 7.81, neg-err 31946.260141, NTOT 13441, n100 4, n200 4, n300 4, n400 4
# >>
# >>Time 41.78, batch 261/828, mu 7.81, neg-err 32584.133924, NTOT 13386, n100 2, n200 2, n300 2, n400 2
# >>
# >>Time 42.31, batch 281/828, mu 8.44, neg-err 33191.688753, NTOT 13738, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 42.70, batch 301/828, mu 8.44, neg-err 33491.216096, NTOT 13666, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 43.08, batch 321/828, mu 8.44, neg-err 33841.302020, NTOT 13618, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 43.35, batch 341/828, mu 8.44, neg-err 34157.382084, NTOT 13546, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 43.76, batch 361/828, mu 8.44, neg-err 34497.253475, NTOT 13498, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 44.15, batch 381/828, mu 8.44, neg-err 34868.010098, NTOT 13425, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 44.54, batch 401/828, mu 8.44, neg-err 35204.023077, NTOT 13377, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 45.04, batch 421/828, mu 8.61, neg-err 35423.811460, NTOT 13745, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 45.44, batch 441/828, mu 8.61, neg-err 35439.156116, NTOT 13692, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 45.79, batch 461/828, mu 8.61, neg-err 35458.095215, NTOT 13614, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 46.11, batch 481/828, mu 8.61, neg-err 35475.658691, NTOT 13562, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 46.49, batch 501/828, mu 8.61, neg-err 35494.250347, NTOT 13484, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 46.88, batch 521/828, mu 8.61, neg-err 35515.298595, NTOT 13432, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 47.27, batch 541/828, mu 8.61, neg-err 35534.098074, NTOT 13354, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 47.76, batch 561/828, mu 7.22, neg-err 35542.286281, NTOT 13696, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 48.15, batch 581/828, mu 7.22, neg-err 35538.830651, NTOT 13650, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 48.50, batch 601/828, mu 7.22, neg-err 35535.164820, NTOT 13581, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 48.75, batch 621/828, mu 7.22, neg-err 35532.865723, NTOT 13535, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 49.09, batch 641/828, mu 7.22, neg-err 35530.288135, NTOT 13466, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 49.43, batch 661/828, mu 7.22, neg-err 35526.493511, NTOT 13420, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 49.76, batch 681/828, mu 7.22, neg-err 35523.286197, NTOT 13352, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 50.31, batch 701/828, mu 8.11, neg-err 35520.493426, NTOT 13745, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 50.64, batch 721/828, mu 8.11, neg-err 35521.257282, NTOT 13667, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 50.92, batch 741/828, mu 8.11, neg-err 35522.085081, NTOT 13615, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 51.24, batch 761/828, mu 8.11, neg-err 35522.497573, NTOT 13537, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 51.57, batch 781/828, mu 8.11, neg-err 35523.016453, NTOT 13484, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 51.89, batch 801/828, mu 8.11, neg-err 35524.780365, NTOT 13406, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 52.21, batch 821/828, mu 8.11, neg-err 35524.876323, NTOT 13353, n100 0, n200 0, n300 0, n400 0
# >>
# >> Time  53s. Running the final template matching pass...
# >>
# >> Time 52.66, batch 1/138,  NTOT 114
# >>
# >>Time 62.34, batch 101/138,  NTOT 10333
# >>
# >>
# >>
# >> 	took 65.6s
# >>
# >> Clustering result wrote to /tmp/kilosort-tmp-JXRCSQTNYZ/firings.mda
# >>
# ========== KiloSort exited with code 0 after 81.1895854473114 sec
# ================================================================================
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_KiloSort8fs7mn27/firings_out.mda -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/KiloSort_0/firings_out.mda
# Saving result object...
# Job: IronClust (version: 0.2.1)
# Timestamp: 2019-03-27 21:26:07
# RUNNING SHELL SCRIPT: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_IronClust1p7rq1ib/run.sh
# >> Running processor (class=KiloSort) ...
# >> Reading timeseries header...
# >> Num. channels = 4, Num. timepoints = 18000000, duration = 10.0 minutes
# >> Creating argfile.txt file...
# >> Running kilosort...
# >> matlab -nosplash -nodisplay -r "addpath('/mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_KiloSortfutv8p5o/processor_source');  p_kilosort('/mnt/home/jjun/src/KiloSort', '/mnt/home/jjun/src/ironclust', '/tmp/kilosort-tmp-RGZQPGEBKS', '/tmp/kilosort-tmp-RGZQPGEBKS/kilosort_dataset/raw.mda', '/tmp/kilosort-tmp-RGZQPGEBKS/kilosort_dataset/geom.csv', '/tmp/kilosort-tmp-RGZQPGEBKS/firings.mda', '/tmp/kilosort-tmp-RGZQPGEBKS/kilosort_dataset/argfile.txt'); quit;"
# >>
# >>
# >>                             < M A T L A B (R) >
# >>
# >>                   Copyright 1984-2018 The MathWorks, Inc.
# >>
# >>                    R2018b (9.5.0.944444) 64-bit (glnxa64)
# >>
# >>                               August 28, 2018
# >>
# >>
# >>
# >>
# >>
# >> To get started, type doc.
# >>
# >> For product information, visit www.mathworks.com.
# >>
# >>
# >>
# >>
# >>
# >> 	Non-Degree Granting Education License -- for use at non-degree granting, nonprofit,
# >>
# >> 	educational organizations only.  Not for government, commercial, or other organizational use.
# >>
# >>
# >>
# >> Running kilosort on /tmp/kilosort-tmp-RGZQPGEBKS/kilosort_dataset/raw.mda
# >>
# >> Time   1s. Loading raw data...
# >>
# >> Time  26s. Channel-whitening filters computed.
# >>
# >> Time  26s. Loading raw data and applying filters...
# >>
# >> Time 35.06. Whitened data written to disk...
# >>
# >> Time 35.07. Preprocessing complete!
# >>
# >> Time  37s. Optimizing templates ...
# >>
# >> Time 36.98, batch 1/828, mu 5.07, neg-err 23081.501953, NTOT 86, n100 0, n200 0, n300 0, n400 0
# >>
# >Time 37.13, batch 21/828, mu 5.07, neg-err 27366.053292, NTOT 1997, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 37.25, batch 41/828, mu 5.07, neg-err 28643.264625, NTOT 3980, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 37.37, batch 61/828, mu 5.07, neg-err 28119.731157, NTOT 5843, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 37.49, batch 81/828, mu 5.07, neg-err 28382.705741, NTOT 7807, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 37.62, batch 101/828, mu 5.07, neg-err 28452.340956, NTOT 9709, n100 0, n200 0, n300 0, n400 0
# >>
# >Time 37.76, batch 121/828, mu 5.07, neg-err 28583.929211, NTOT 11690, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 40.54, batch 141/828, mu 7.81, neg-err 28695.197443, NTOT 13807, n100 17, n200 17, n300 17, n400 17
# >>
# >> Running processor (class=KiloSort) ...
# >>Time 40.92, batch 161/828, mu 7.81, neg-err 29311.802925, NTOT 13722, n100 14, n200 14, n300 14, n400 14
# >> Reading timeseries header...
# >>
# >> Num. channels = 4, Num. timepoints = 18000000, duration = 10.0 minutes
# >>Time 41.31, batch 181/828, mu 7.81, neg-err 29987.965700, NTOT 13666, n100 12, n200 12, n300 12, n400 12
# >> Creating argfile.txt file...
# >>
# >> Running kilosort...
# >>Time 41.69, batch 201/828, mu 7.81, neg-err 30608.984149, NTOT 13582, n100 9, n200 9, n300 9, n400 9
# >> matlab -nosplash -nodisplay -r "addpath('/mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_KiloSort030qoi4c/processor_source');  p_kilosort('/mnt/home/jjun/src/KiloSort', '/mnt/home/jjun/src/ironclust', '/tmp/kilosort-tmp-AYPRUSCPRU', '/tmp/kilosort-tmp-AYPRUSCPRU/kilosort_dataset/raw.mda', '/tmp/kilosort-tmp-AYPRUSCPRU/kilosort_dataset/geom.csv', '/tmp/kilosort-tmp-AYPRUSCPRU/firings.mda', '/tmp/kilosort-tmp-AYPRUSCPRU/kilosort_dataset/argfile.txt'); quit;"
# >>
# >>
# >>
# >>Time 41.94, batch 221/828, mu 7.81, neg-err 31259.596467, NTOT 13524, n100 7, n200 7, n300 7, n400 7
# >>                             < M A T L A B (R) >
# >>
# >>
# >>                   Copyright 1984-2018 The MathWorks, Inc.
# >>Time 42.31, batch 241/828, mu 7.81, neg-err 31945.619367, NTOT 13441, n100 4, n200 4, n300 4, n400 4
# >>
# >>
# >>                    R2018b (9.5.0.944444) 64-bit (glnxa64)
# >>Time 42.69, batch 261/828, mu 7.81, neg-err 32583.378326, NTOT 13386, n100 2, n200 2, n300 2, n400 2
# >>
# >>
# >>                               August 28, 2018
# >>Time 43.26, batch 281/828, mu 8.44, neg-err 33190.783642, NTOT 13738, n100 0, n200 0, n300 0, n400 0
# >>
# >>
# >>
# >>Time 43.67, batch 301/828, mu 8.44, neg-err 33490.121009, NTOT 13666, n100 0, n200 0, n300 0, n400 0
# >>
# >>
# >>Time 44.06, batch 321/828, mu 8.44, neg-err 33840.003751, NTOT 13618, n100 0, n200 0, n300 0, n400 0
# >>
# >>
# >>
# >>Time 44.45, batch 341/828, mu 8.44, neg-err 34155.923142, NTOT 13546, n100 0, n200 0, n300 0, n400 0
# >>
# >> To get started, type doc.
# >>Time 44.72, batch 361/828, mu 8.44, neg-err 34495.661791, NTOT 13498, n100 0, n200 0, n300 0, n400 0
# >>
# >>
# >> For product information, visit www.mathworks.com.
# >>Time 45.12, batch 381/828, mu 8.44, neg-err 34866.256475, NTOT 13425, n100 0, n200 0, n300 0, n400 0
# >>
# >>
# >>Time 45.50, batch 401/828, mu 8.44, neg-err 35202.136655, NTOT 13377, n100 0, n200 0, n300 0, n400 0
# >>
# >>
# >>
# >>Time 45.96, batch 421/828, mu 8.61, neg-err 35421.913886, NTOT 13745, n100 0, n200 0, n300 0, n400 0
# >>
# >>
# >>
# >>Time 46.34, batch 441/828, mu 8.61, neg-err 35437.487963, NTOT 13692, n100 0, n200 0, n300 0, n400 0
# >> 	Non-Degree Granting Education License -- for use at non-degree granting, nonprofit,
# >>
# >>
# >>Time 46.73, batch 461/828, mu 8.61, neg-err 35459.244332, NTOT 13615, n100 0, n200 0, n300 0, n400 0
# >> 	educational organizations only.  Not for government, commercial, or other organizational use.
# >>
# >>Time 47.12, batch 481/828, mu 8.61, neg-err 35477.044292, NTOT 13563, n100 0, n200 0, n300 0, n400 0
# >>
# >>
# >>
# >>Time 47.39, batch 501/828, mu 8.61, neg-err 35495.907120, NTOT 13485, n100 0, n200 0, n300 0, n400 0
# >>
# >>
# >> Running kilosort on /tmp/kilosort-tmp-AYPRUSCPRU/kilosort_dataset/raw.mda
# >>Time 47.79, batch 521/828, mu 8.61, neg-err 35517.279969, NTOT 13433, n100 0, n200 0, n300 0, n400 0
# >>
# >>
# >>Time 48.17, batch 541/828, mu 8.61, neg-err 35536.339256, NTOT 13355, n100 0, n200 0, n300 0, n400 0
# >> Time   1s. Loading raw data...
# >>
# >>
# >>Time 48.63, batch 561/828, mu 7.22, neg-err 35544.696240, NTOT 13697, n100 0, n200 0, n300 0, n400 0
# >> Time  25s. Channel-whitening filters computed.
# >>
# >>
# >>Time 48.97, batch 581/828, mu 7.22, neg-err 35541.267684, NTOT 13651, n100 0, n200 0, n300 0, n400 0
# >> Time  25s. Loading raw data and applying filters...
# >>
# >>
# >>Time 49.31, batch 601/828, mu 7.22, neg-err 35535.707888, NTOT 13582, n100 0, n200 0, n300 0, n400 0
# >> Time 34.61. Whitened data written to disk...
# >>
# >>
# >> Time 34.61. Preprocessing complete!
# >>Time 49.64, batch 621/828, mu 7.22, neg-err 35533.429553, NTOT 13536, n100 0, n200 0, n300 0, n400 0
# >>
# >>
# >> Time  36s. Optimizing templates ...
# >>Time 49.83, batch 641/828, mu 7.22, neg-err 35530.863246, NTOT 13467, n100 0, n200 0, n300 0, n400 0
# >>
# >>
# >> Time 36.04, batch 1/828, mu 5.07, neg-err 23081.503906, NTOT 86, n100 0, n200 0, n300 0, n400 0
# >>Time 50.06, batch 661/828, mu 7.22, neg-err 35527.090176, NTOT 13421, n100 0, n200 0, n300 0, n400 0
# >>
# >>
# >Time 36.23, batch 21/828, mu 5.07, neg-err 27366.053943, NTOT 1997, n100 0, n200 0, n300 0, n400 0
# >>Time 50.39, batch 681/828, mu 7.22, neg-err 35523.893887, NTOT 13353, n100 0, n200 0, n300 0, n400 0
# >>
# >>
# >>Time 36.43, batch 41/828, mu 5.07, neg-err 28643.265244, NTOT 3980, n100 0, n200 0, n300 0, n400 0
# >>Time 50.85, batch 701/828, mu 8.11, neg-err 35521.109241, NTOT 13746, n100 0, n200 0, n300 0, n400 0
# >>
# >>
# >>Time 36.62, batch 61/828, mu 5.07, neg-err 28119.731541, NTOT 5843, n100 0, n200 0, n300 0, n400 0
# >>Time 51.17, batch 721/828, mu 8.11, neg-err 35521.862949, NTOT 13668, n100 0, n200 0, n300 0, n400 0
# >>
# >>
# >>Time 36.83, batch 81/828, mu 5.07, neg-err 28382.706055, NTOT 7807, n100 0, n200 0, n300 0, n400 0
# >>Time 51.49, batch 741/828, mu 8.11, neg-err 35522.090955, NTOT 13615, n100 0, n200 0, n300 0, n400 0
# >>
# >>
# >>Time 37.03, batch 101/828, mu 5.07, neg-err 28452.341168, NTOT 9709, n100 0, n200 0, n300 0, n400 0
# >>Time 51.82, batch 761/828, mu 8.11, neg-err 35522.500340, NTOT 13537, n100 0, n200 0, n300 0, n400 0
# >>
# >Time 37.25, batch 121/828, mu 5.07, neg-err 28583.929421, NTOT 11690, n100 0, n200 0, n300 0, n400 0
# >>
# >>
# >>Time 52.12, batch 781/828, mu 8.11, neg-err 35523.007048, NTOT 13484, n100 0, n200 0, n300 0, n400 0
# >>Time 40.01, batch 141/828, mu 7.81, neg-err 28695.187040, NTOT 13807, n100 17, n200 17, n300 17, n400 17
# >>
# >>
# >>Time 52.27, batch 801/828, mu 8.11, neg-err 35524.767592, NTOT 13406, n100 0, n200 0, n300 0, n400 0
# >>Time 40.28, batch 161/828, mu 7.81, neg-err 29311.732047, NTOT 13722, n100 14, n200 14, n300 14, n400 14
# >>
# >>
# >>Time 52.49, batch 821/828, mu 8.11, neg-err 35524.861866, NTOT 13353, n100 0, n200 0, n300 0, n400 0
# >>Time 40.56, batch 181/828, mu 7.81, neg-err 29987.833439, NTOT 13666, n100 12, n200 12, n300 12, n400 12
# >>
# >>
# >> Time  53s. Running the final template matching pass...
# >>Time 40.82, batch 201/828, mu 7.81, neg-err 30608.781788, NTOT 13582, n100 9, n200 9, n300 9, n400 9
# >>
# >>
# >> Time 52.86, batch 1/138,  NTOT 114
# >>Time 41.14, batch 221/828, mu 7.81, neg-err 31259.340382, NTOT 13524, n100 7, n200 7, n300 7, n400 7
# >>
# >>
# >>Time 62.53, batch 101/138,  NTOT 10337
# >>Time 41.52, batch 241/828, mu 7.81, neg-err 31945.312811, NTOT 13441, n100 4, n200 4, n300 4, n400 4
# >>
# >>
# >>
# >>Time 41.91, batch 261/828, mu 7.81, neg-err 32583.009398, NTOT 13386, n100 2, n200 2, n300 2, n400 2
# >>
# >>
# >> 	took 65.5s
# >>Time 42.50, batch 281/828, mu 8.44, neg-err 33190.388375, NTOT 13738, n100 0, n200 0, n300 0, n400 0
# >>
# >>
# >> Clustering result wrote to /tmp/kilosort-tmp-RGZQPGEBKS/firings.mda
# >>Time 42.89, batch 301/828, mu 8.44, neg-err 33489.797696, NTOT 13666, n100 0, n200 0, n300 0, n400 0
# >>
# >>
# ========== KiloSort exited with code 0 after 82.25200176239014 sec
# >>Time 43.28, batch 321/828, mu 8.44, neg-err 33839.761775, NTOT 13618, n100 0, n200 0, n300 0, n400 0
# ================================================================================
# >>
# >>Time 43.56, batch 341/828, mu 8.44, neg-err 34155.759277, NTOT 13546, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 43.95, batch 361/828, mu 8.44, neg-err 34495.554412, NTOT 13498, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 44.35, batch 381/828, mu 8.44, neg-err 34866.212784, NTOT 13425, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 44.75, batch 401/828, mu 8.44, neg-err 35202.150497, NTOT 13377, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 45.27, batch 421/828, mu 8.61, neg-err 35421.982033, NTOT 13745, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 45.67, batch 441/828, mu 8.61, neg-err 35437.532361, NTOT 13692, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 46.03, batch 461/828, mu 8.61, neg-err 35456.761330, NTOT 13614, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 46.34, batch 481/828, mu 8.61, neg-err 35474.552076, NTOT 13562, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 46.72, batch 501/828, mu 8.61, neg-err 35493.405196, NTOT 13484, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 47.11, batch 521/828, mu 8.61, neg-err 35514.765420, NTOT 13432, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 47.50, batch 541/828, mu 8.61, neg-err 35533.814517, NTOT 13354, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 48.03, batch 561/828, mu 7.22, neg-err 35542.162739, NTOT 13696, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 48.42, batch 581/828, mu 7.22, neg-err 35538.721899, NTOT 13650, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 48.77, batch 601/828, mu 7.22, neg-err 35535.069286, NTOT 13581, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 49.02, batch 621/828, mu 7.22, neg-err 35532.780769, NTOT 13535, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 49.36, batch 641/828, mu 7.22, neg-err 35530.209310, NTOT 13466, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 49.70, batch 661/828, mu 7.22, neg-err 35526.429617, NTOT 13420, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 50.02, batch 681/828, mu 7.22, neg-err 35523.232606, NTOT 13352, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 50.51, batch 701/828, mu 8.11, neg-err 35520.460315, NTOT 13745, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 50.84, batch 721/828, mu 8.11, neg-err 35521.526381, NTOT 13668, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 51.12, batch 741/828, mu 8.11, neg-err 35522.373627, NTOT 13616, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 51.44, batch 761/828, mu 8.11, neg-err 35522.806733, NTOT 13538, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 51.77, batch 781/828, mu 8.11, neg-err 35523.324509, NTOT 13485, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 52.09, batch 801/828, mu 8.11, neg-err 35525.108278, NTOT 13407, n100 0, n200 0, n300 0, n400 0
# >>
# >>Time 52.42, batch 821/828, mu 8.11, neg-err 35525.225749, NTOT 13354, n100 0, n200 0, n300 0, n400 0
# >>
# >> Time  53s. Running the final template matching pass...
# >>
# >> Time 52.86, batch 1/138,  NTOT 114
# >>
# >>Time 62.50, batch 101/138,  NTOT 10332
# >>
# >>
# >>
# >> 	took 65.9s
# >>
# >> Clustering result wrote to /tmp/kilosort-tmp-AYPRUSCPRU/firings.mda
# >>
# ========== KiloSort exited with code 0 after 82.17713594436646 sec
# ================================================================================
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_KiloSorty3zw94br/firings_out.mda -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/KiloSort_2/firings_out.mda
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_KiloSortodm8s7z7/firings_out.mda -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/KiloSort_1/firings_out.mda
# BATCH  running: 5 running, 1 finished, 0 errors -- 12 total jobs
# Saving result object...
# Saving result object...
# Job: IronClust (version: 0.2.1)
# Timestamp: 2019-03-27 21:26:08
# RUNNING SHELL SCRIPT: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_IronClusth6mhwwmd/run.sh
# Job: IronClust (version: 0.2.1)
# Timestamp: 2019-03-27 21:26:08
# RUNNING SHELL SCRIPT: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_IronClust4jgnq48z/run.sh
# BATCH  running: 3 running, 3 finished, 0 errors -- 12 total jobs
# BATCH  running: 5 running, 3 finished, 0 errors -- 12 total jobs
# Uploading result for job 3
# Uploading result for job 2
# Uploading result for job 0
# Uploading result for job 1
# BATCH  running: 8 running, 0 finished, 0 errors -- 12 total jobs
# Uploading result for job 2
# Uploading result for job 0
# Uploading result for job 1
# >>
# >>                             < M A T L A B (R) >
# >>                   Copyright 1984-2018 The MathWorks, Inc.
# >>                    R2018b (9.5.0.944444) 64-bit (glnxa64)
# >>                               August 28, 2018
# >>
# >>
# >> To get started, type doc.
# >> For product information, visit www.mathworks.com.
# >>
# >>
# >> 	Non-Degree Granting Education License -- for use at non-degree granting, nonprofit,
# >> 	educational organizations only.  Not for government, commercial, or other organizational use.
# >>
# >> Created /tmp/ironclust-tmp-RUFEKWSCQF/raw_geom.prm
# >> Memory cleared on CPU and GPU
# >> Performing "irc detect", "irc sort" operations.
# >> File 1/1: detecting spikes from /tmp/ironclust-tmp-RUFEKWSCQF/ironclust_dataset/raw.mda
# >> Processing 1/1 of file 1/1...
# >> 	Loading from file...took 0.5s
# >> 	Filtering spikes...
# >> 	Running ms_bandpass_filter
# >> 	...................................
# >> 	took 2.2s (fGpu=1)
# >> 	took 2.3s
# >> 	Detecting spikes from each channel.
# >> 		....
# >> 		Detected 47530 spikes from 4 sites; took 0.4s.
# >> 	Merging spikes...	13966 spiking events found; took 0.1s
# >> 	Extracting features...	took 1.2s
# >> File 1/1 took 5.6s (288.0 MB, 51.7 MB/s, x107.7 realtime)
# >> Loading /tmp/ironclust-tmp-RUFEKWSCQF/raw_geom_spkraw.jrc took 0.0s
# >> Loading /tmp/ironclust-tmp-RUFEKWSCQF/raw_geom_spkwav.jrc took 0.0s
# >> Loading /tmp/ironclust-tmp-RUFEKWSCQF/raw_geom_spkfet.jrc took 0.0s
# >> Detection took 5.6s for /tmp/ironclust-tmp-RUFEKWSCQF/raw_geom.prm
# >> Saving 0.UserData to /tmp/ironclust-tmp-RUFEKWSCQF/raw_geom_jrc.mat...
# >> Saving a struct to /tmp/ironclust-tmp-RUFEKWSCQF/raw_geom_jrc.mat...
# >> 	took 0.0s.
# >> Full parameter settings are exported to /tmp/ironclust-tmp-RUFEKWSCQF/raw_geom_full.prm
# >> Clustering
# >> Calculating Rho
# >> 	using GPU.
# >> 	....
# >> 	took 0.1s
# >> Calculating Delta
# >> 	using GPU.
# >> 	....
# >> 	took 0.1s
# >> assigning clusters, nClu:26
# >> S_clu_peak_merge_: 25->16 cluster centers (knn_merge_thresh=1)
# >>
# >> 	took 0.1s. Removed 10 clusters having <30 spikes: 26->16
# >> 	Clustering took 0.2 s
# >>
# >> auto-merging...
# >> Template matching (post-hoc)
# >> 	Computing template
# >> 	...............
# >> 	took 0.3s
# >> 	Reassigning spikes
# >> 	...
# >> 	Reassigned 5.9% spikes, took 0.7s
# >> Merging templates
# >> 	...............
# >> Merged 6 waveforms (16->10), took 0.2s
# >> Calculating cluster mean waveform.
# >> 	....................
# >> 	took 0.3s
# >> Computing waveform correlation...	took 0.0s
# >> Calculating cluster mean waveform.
# >> 	....................
# >> 	took 0.1s
# >> Computing waveform correlation...	took 0.0s
# >> Computing self correlation
# >> 	..........
# >> 	took 0.0s
# >> Computing self correlation
# >> 	..........
# >> 	took 0.0s
# >> Calculating cluster quality...
# >> 	took 0.1s
# >>
# >> 	auto-merging took 1.6s
# >> Sorting took 1.8s for /tmp/ironclust-tmp-RUFEKWSCQF/raw_geom.prm
# >> Saving 0.UserData to /tmp/ironclust-tmp-RUFEKWSCQF/raw_geom_jrc.mat...
# >> Saving a struct to /tmp/ironclust-tmp-RUFEKWSCQF/raw_geom_jrc.mat...
# >> 	took 0.0s.
# >> Full parameter settings are exported to /tmp/ironclust-tmp-RUFEKWSCQF/raw_geom_full.prm
# >> Recording file
# >>     Recording file          /tmp/ironclust-tmp-RUFEKWSCQF/ironclust_dataset/raw.mda
# >>     Probe file              /tmp/ironclust-tmp-RUFEKWSCQF/geom.prb
# >>     Recording Duration      599.8s
# >>     #Sites                  4
# >> Events
# >>     #Spikes                 13966
# >>     Feature                 gpca
# >>     #Sites/event            4
# >>     #Features/event         12
# >>     #Loads                  1
# >> Cluster
# >>     #Clusters               10
# >>     #Unique events          13938
# >>     min. spk/clu            30
# >> Runtime (s)
# >>     Detect + feature        5.6s
# >>     Cluster + auto-merge    1.8s
# >>         Cluster             0.2s
# >>         auto-merge          1.6s
# >>     Total                   7.5s
# >>     Runtime speed           x80.5 realtime
# >> Added path to /mnt/home/jjun/src/ironclust/matlab/mdaio/
# >> Writing to /tmp/ironclust-tmp-RUFEKWSCQF/firings.mda took 0.1s
# >> Output to /tmp/ironclust-tmp-RUFEKWSCQF/firings.mda
# >> Clustering result wrote to /tmp/ironclust-tmp-RUFEKWSCQF/firings.mda
# >> Running processor (class=IronClust) ...
# >> Reading timeseries header...
# >> Num. channels = 4, Num. timepoints = 18000000, duration = 10.0 minutes
# >> Creating argfile.txt...
# >> Running IronClust...
# >> matlab -nosplash -nodisplay -r "addpath('/mnt/home/jjun/src/ironclust', '/mnt/home/jjun/src/ironclust/matlab', '/mnt/home/jjun/src/ironclust/matlab/mdaio'); p_ironclust('/tmp/ironclust-tmp-RUFEKWSCQF', '/tmp/ironclust-tmp-RUFEKWSCQF/ironclust_dataset/raw.mda', '/tmp/ironclust-tmp-RUFEKWSCQF/ironclust_dataset/geom.csv', '', '', '/tmp/ironclust-tmp-RUFEKWSCQF/firings.mda', '/tmp/ironclust-tmp-RUFEKWSCQF/ironclust_dataset/argfile.txt'); quit;"
# ========== IronClust exited with code 0 after 24.473581314086914 sec
# ================================================================================
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_IronClustch7wtpg6/firings_out.mda -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/IronClust_static_0/firings_out.mda
# Saving result object...
# Job: MountainSort4 (version: 4.2.0)
# Timestamp: 2019-03-27 21:26:30
# RUNNING SHELL SCRIPT: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_MountainSort45obfwnid/run.sh
# >>
# >>                             < M A T L A B (R) >
# >>                   Copyright 1984-2018 The MathWorks, Inc.
# >>                    R2018b (9.5.0.944444) 64-bit (glnxa64)
# >>                               August 28, 2018
# >>
# >>
# >> To get started, type doc.
# >> For product information, visit www.mathworks.com.
# >>
# >>
# >> 	Non-Degree Granting Education License -- for use at non-degree granting, nonprofit,
# >> 	educational organizations only.  Not for government, commercial, or other organizational use.
# >>
# >> Created /tmp/ironclust-tmp-DXJFWCJOFG/raw_geom.prm
# >> Memory cleared on CPU and GPU
# >> Performing "irc detect", "irc sort" operations.
# >> File 1/1: detecting spikes from /tmp/ironclust-tmp-DXJFWCJOFG/ironclust_dataset/raw.mda
# >> Processing 1/1 of file 1/1...
# >> 	Loading from file...took 0.5s
# >> 	Filtering spikes...
# >> 	Running ms_bandpass_filter
# >> 	...................................
# >> 	took 2.2s (fGpu=1)
# >> 	took 2.3s
# >> 	Detecting spikes from each channel.
# >> 		....
# >> 		Detected 47530 spikes from 4 sites; took 0.4s.
# >> 	Merging spikes...	13966 spiking events found; took 0.1s
# >> 	Extracting features...	took 1.1s
# >> File 1/1 took 5.4s (288.0 MB, 53.8 MB/s, x112.1 realtime)
# >> Loading /tmp/ironclust-tmp-DXJFWCJOFG/raw_geom_spkraw.jrc took 0.0s
# >> Loading /tmp/ironclust-tmp-DXJFWCJOFG/raw_geom_spkwav.jrc took 0.0s
# >> Loading /tmp/ironclust-tmp-DXJFWCJOFG/raw_geom_spkfet.jrc took 0.0s
# >> Detection took 5.4s for /tmp/ironclust-tmp-DXJFWCJOFG/raw_geom.prm
# >> Saving 0.UserData to /tmp/ironclust-tmp-DXJFWCJOFG/raw_geom_jrc.mat...
# >> Saving a struct to /tmp/ironclust-tmp-DXJFWCJOFG/raw_geom_jrc.mat...
# >> 	took 0.0s.
# >> Full parameter settings are exported to /tmp/ironclust-tmp-DXJFWCJOFG/raw_geom_full.prm
# >> Clustering
# >> Calculating Rho
# >> 	using GPU.
# >> 	....
# >> 	took 0.1s
# >> Calculating Delta
# >> 	using GPU.
# >> 	....
# >> 	took 0.1s
# >> assigning clusters, nClu:26
# >> S_clu_peak_merge_: 25->16 cluster centers (knn_merge_thresh=1)
# >>
# >> 	took 0.0s. Removed 10 clusters having <30 spikes: 26->16
# >> 	Clustering took 0.2 s
# >>
# >> auto-merging...
# >> Template matching (post-hoc)
# >> 	Computing template
# >> 	...............
# >> 	took 0.3s
# >> 	Reassigning spikes
# >> 	...
# >> 	Reassigned 5.9% spikes, took 0.7s
# >> Merging templates
# >> 	...............
# >> Merged 6 waveforms (16->10), took 0.1s
# >> Calculating cluster mean waveform.
# >> 	....................
# >> 	took 0.3s
# >> Computing waveform correlation...	took 0.1s
# >> Calculating cluster mean waveform.
# >> 	....................
# >> 	took 0.2s
# >> Computing waveform correlation...	took 0.0s
# >> Computing self correlation
# >> 	..........
# >> 	took 0.1s
# >> Computing self correlation
# >> 	..........
# >> 	took 0.0s
# >> Calculating cluster quality...
# >> 	took 0.1s
# >>
# >> 	auto-merging took 1.6s
# >> Sorting took 1.8s for /tmp/ironclust-tmp-DXJFWCJOFG/raw_geom.prm
# >> Saving 0.UserData to /tmp/ironclust-tmp-DXJFWCJOFG/raw_geom_jrc.mat...
# >> Saving a struct to /tmp/ironclust-tmp-DXJFWCJOFG/raw_geom_jrc.mat...
# >> 	took 0.0s.
# >> Full parameter settings are exported to /tmp/ironclust-tmp-DXJFWCJOFG/raw_geom_full.prm
# >> Recording file
# >>     Recording file          /tmp/ironclust-tmp-DXJFWCJOFG/ironclust_dataset/raw.mda
# >>     Probe file              /tmp/ironclust-tmp-DXJFWCJOFG/geom.prb
# >>     Recording Duration      599.8s
# >>     #Sites                  4
# >> Events
# >>     #Spikes                 13966
# >>     Feature                 gpca
# >>     #Sites/event            4
# >>     #Features/event         12
# >>     #Loads                  1
# >> Cluster
# >>     #Clusters               10
# >>     #Unique events          13938
# >>     min. spk/clu            30
# >> Runtime (s)
# >>     Detect + feature        5.4s
# >>     Cluster + auto-merge    1.8s
# >>         Cluster             0.2s
# >>         auto-merge          1.7s
# >>     Total                   7.2s
# >>     Runtime speed           x82.9 realtime
# >> Added path to /mnt/home/jjun/src/ironclust/matlab/mdaio/
# >> Writing to /tmp/ironclust-tmp-DXJFWCJOFG/firings.mda took 0.1s
# >> Output to /tmp/ironclust-tmp-DXJFWCJOFG/firings.mda
# >> Clustering result wrote to /tmp/ironclust-tmp-DXJFWCJOFG/firings.mda
# >> Running processor (class=IronClust) ...
# >> Reading timeseries header...
# >> Num. channels = 4, Num. timepoints = 18000000, duration = 10.0 minutes
# >> Creating argfile.txt...
# >> Running IronClust...
# >> matlab -nosplash -nodisplay -r "addpath('/mnt/home/jjun/src/ironclust', '/mnt/home/jjun/src/ironclust/matlab', '/mnt/home/jjun/src/ironclust/matlab/mdaio'); p_ironclust('/tmp/ironclust-tmp-DXJFWCJOFG', '/tmp/ironclust-tmp-DXJFWCJOFG/ironclust_dataset/raw.mda', '/tmp/ironclust-tmp-DXJFWCJOFG/ironclust_dataset/geom.csv', '', '', '/tmp/ironclust-tmp-DXJFWCJOFG/firings.mda', '/tmp/ironclust-tmp-DXJFWCJOFG/ironclust_dataset/argfile.txt'); quit;"
# ========== IronClust exited with code 0 after 23.886905670166016 sec
# ================================================================================
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_IronClust8hm1l2o_/firings_out.mda -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/IronClust_static_1/firings_out.mda
# Saving result object...
# Job: MountainSort4 (version: 4.2.0)
# Timestamp: 2019-03-27 21:26:31
# RUNNING SHELL SCRIPT: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_MountainSort4axbwdta0/run.sh
# >>
# >>                             < M A T L A B (R) >
# >>                   Copyright 1984-2018 The MathWorks, Inc.
# >>                    R2018b (9.5.0.944444) 64-bit (glnxa64)
# >>                               August 28, 2018
# >>
# >>
# >> To get started, type doc.
# >> For product information, visit www.mathworks.com.
# >>
# >>
# >> 	Non-Degree Granting Education License -- for use at non-degree granting, nonprofit,
# >> 	educational organizations only.  Not for government, commercial, or other organizational use.
# >>
# >> Created /tmp/ironclust-tmp-ROJBMYTBRJ/raw_geom.prm
# >> Memory cleared on CPU and GPU
# >> Performing "irc detect", "irc sort" operations.
# >> File 1/1: detecting spikes from /tmp/ironclust-tmp-ROJBMYTBRJ/ironclust_dataset/raw.mda
# >> Processing 1/1 of file 1/1...
# >> 	Loading from file...took 0.6s
# >> 	Filtering spikes...
# >> 	Running ms_bandpass_filter
# >> 	...................................
# >> 	took 1.9s (fGpu=1)
# >> 	took 2.1s
# >> 	Detecting spikes from each channel.
# >> 		....
# >> 		Detected 47530 spikes from 4 sites; took 0.4s.
# >> 	Merging spikes...	13966 spiking events found; took 0.1s
# >> 	Extracting features...	took 1.1s
# >> File 1/1 took 5.3s (288.0 MB, 54.6 MB/s, x113.7 realtime)
# >> Loading /tmp/ironclust-tmp-ROJBMYTBRJ/raw_geom_spkraw.jrc took 0.0s
# >> Loading /tmp/ironclust-tmp-ROJBMYTBRJ/raw_geom_spkwav.jrc took 0.0s
# >> Loading /tmp/ironclust-tmp-ROJBMYTBRJ/raw_geom_spkfet.jrc took 0.0s
# >> Detection took 5.3s for /tmp/ironclust-tmp-ROJBMYTBRJ/raw_geom.prm
# >> Saving 0.UserData to /tmp/ironclust-tmp-ROJBMYTBRJ/raw_geom_jrc.mat...
# >> Saving a struct to /tmp/ironclust-tmp-ROJBMYTBRJ/raw_geom_jrc.mat...
# >> 	took 0.0s.
# >> Full parameter settings are exported to /tmp/ironclust-tmp-ROJBMYTBRJ/raw_geom_full.prm
# >> Clustering
# >> Calculating Rho
# >> 	using GPU.
# >> 	....
# >> 	took 0.1s
# >> Calculating Delta
# >> 	using GPU.
# >> 	....
# >> 	took 0.1s
# >> assigning clusters, nClu:26
# >> S_clu_peak_merge_: 25->16 cluster centers (knn_merge_thresh=1)
# >>
# >> 	took 0.0s. Removed 10 clusters having <30 spikes: 26->16
# >> 	Clustering took 0.2 s
# >>
# >> auto-merging...
# >> Template matching (post-hoc)
# >> 	Computing template
# >> 	...............
# >> 	took 0.3s
# >> 	Reassigning spikes
# >> 	...
# >> 	Reassigned 5.9% spikes, took 0.6s
# >> Merging templates
# >> 	...............
# >> Merged 6 waveforms (16->10), took 0.1s
# >> Calculating cluster mean waveform.
# >>
# >> 	....................
# >> 	took 0.3s
# >>                             < M A T L A B (R) >
# >> Computing waveform correlation...	took 0.1s
# >>                   Copyright 1984-2018 The MathWorks, Inc.
# >> Calculating cluster mean waveform.
# >>                    R2018b (9.5.0.944444) 64-bit (glnxa64)
# >> 	....................
# >>                               August 28, 2018
# >> 	took 0.1s
# >>
# >> Computing waveform correlation...	took 0.0s
# >> Computing self correlation
# >>
# >> 	..........
# >> To get started, type doc.
# >> 	took 0.0s
# >> For product information, visit www.mathworks.com.
# >> Computing self correlation
# >>
# >> 	..........
# >>
# >> 	took 0.0s
# >> 	Non-Degree Granting Education License -- for use at non-degree granting, nonprofit,
# >> Calculating cluster quality...
# >> 	educational organizations only.  Not for government, commercial, or other organizational use.
# >> 	took 0.1s
# >>
# >>
# >> Created /tmp/ironclust-tmp-HILZXDRJMB/raw_geom.prm
# >> 	auto-merging took 1.5s
# >> Memory cleared on CPU and GPU
# >> Sorting took 1.8s for /tmp/ironclust-tmp-ROJBMYTBRJ/raw_geom.prm
# >> Saving 0.UserData to /tmp/ironclust-tmp-ROJBMYTBRJ/raw_geom_jrc.mat...
# >> Performing "irc detect", "irc sort" operations.
# >> Saving a struct to /tmp/ironclust-tmp-ROJBMYTBRJ/raw_geom_jrc.mat...
# >> File 1/1: detecting spikes from /tmp/ironclust-tmp-HILZXDRJMB/ironclust_dataset/raw.mda
# >> 	took 0.0s.
# >> Processing 1/1 of file 1/1...
# >> Full parameter settings are exported to /tmp/ironclust-tmp-ROJBMYTBRJ/raw_geom_full.prm
# >> 	Loading from file...took 0.5s
# >> Recording file
# >>     Recording file          /tmp/ironclust-tmp-ROJBMYTBRJ/ironclust_dataset/raw.mda
# >> 	Filtering spikes...
# >>     Probe file              /tmp/ironclust-tmp-ROJBMYTBRJ/geom.prb
# >> 	Running ms_bandpass_filter
# >>     Recording Duration      599.8s
# >>     #Sites                  4
# >> 	...................................
# >> Events
# >> 	took 2.1s (fGpu=1)
# >>     #Spikes                 13966
# >>     Feature                 gpca
# >> 	took 2.2s
# >>     #Sites/event            4
# >> 	Detecting spikes from each channel.
# >>     #Features/event         12
# >>     #Loads                  1
# >> 		....
# >> Cluster
# >> 		Detected 47530 spikes from 4 sites; took 0.3s.
# >>     #Clusters               10
# >>     #Unique events          13938
# >> 	Merging spikes...	13966 spiking events found; took 0.1s
# >>     min. spk/clu            30
# >> 	Extracting features...	took 1.1s
# >> Runtime (s)
# >>     Detect + feature        5.3s
# >> File 1/1 took 5.2s (288.0 MB, 55.1 MB/s, x114.8 realtime)
# >>     Cluster + auto-merge    1.8s
# >> Loading /tmp/ironclust-tmp-HILZXDRJMB/raw_geom_spkraw.jrc took 0.0s
# >>         Cluster             0.2s
# >>         auto-merge          1.6s
# >> Loading /tmp/ironclust-tmp-HILZXDRJMB/raw_geom_spkwav.jrc took 0.0s
# >>     Total                   7.1s
# >> Loading /tmp/ironclust-tmp-HILZXDRJMB/raw_geom_spkfet.jrc took 0.0s
# >>     Runtime speed           x84.7 realtime
# >> Added path to /mnt/home/jjun/src/ironclust/matlab/mdaio/
# >> Detection took 5.3s for /tmp/ironclust-tmp-HILZXDRJMB/raw_geom.prm
# >> Writing to /tmp/ironclust-tmp-ROJBMYTBRJ/firings.mda took 0.1s
# >> Saving 0.UserData to /tmp/ironclust-tmp-HILZXDRJMB/raw_geom_jrc.mat...
# >> Output to /tmp/ironclust-tmp-ROJBMYTBRJ/firings.mda
# >> Clustering result wrote to /tmp/ironclust-tmp-ROJBMYTBRJ/firings.mda
# >> Saving a struct to /tmp/ironclust-tmp-HILZXDRJMB/raw_geom_jrc.mat...
# >> Running processor (class=IronClust) ...
# >> Reading timeseries header...
# >> 	took 0.0s.
# >> Num. channels = 4, Num. timepoints = 18000000, duration = 10.0 minutes
# >> Full parameter settings are exported to /tmp/ironclust-tmp-HILZXDRJMB/raw_geom_full.prm
# >> Creating argfile.txt...
# >> Running IronClust...
# >> Clustering
# ...
# Realizing sha1://d1e51bafc0b8afbad23742e695aaa1d548b7ac42/firings_true.mda...
# Realizing sha1://2ad7c779a9f06d548d59a51a04d57b935b1c12a5/firings_out.mda...
# Realizing sha1://bc4c4660b6ca5d997705ed34f8ce909bc54b615a/firings_out.mda...
# Job: GenSortingComparisonTable (version: 0.2.0)
# Timestamp: 2019-03-27 21:27:22
# Job: GenSortingComparisonTable (version: 0.2.0)
# Timestamp: 2019-03-27 21:27:22
# Job: GenSortingComparisonTable (version: 0.2.0)
# Timestamp: 2019-03-27 21:27:22
# BATCH  running: 0 running, 0 finished, 0 errors -- 12 total jobs
# Job: GenSortingComparisonTable (version: 0.2.0)
# Timestamp: 2019-03-27 21:27:22
# RUNNING SHELL SCRIPT: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_GenSortingComparisonTable55o01213/run.sh
# RUNNING SHELL SCRIPT: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_GenSortingComparisonTable5znbl3m9/run.sh
# RUNNING SHELL SCRIPT: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_GenSortingComparisonTable9bw112w6/run.sh
# RUNNING SHELL SCRIPT: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_GenSortingComparisonTablebaw06soe/run.sh
# BATCH  running: 4 running, 0 finished, 0 errors -- 12 total jobs
# >> Running processor (class=GenSortingComparisonTable) ...
# ========== GenSortingComparisonTable exited with code 0 after 1.3419451713562012 sec
# ================================================================================
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_GenSortingComparisonTablejwzpikdh/json_out.json -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/KiloSort_3/sorting_comparison.json
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_GenSortingComparisonTablejwzpikdh/html_out.html -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/KiloSort_3/sorting_comparison.html
# >> Running processor (class=GenSortingComparisonTable) ...
# ========== GenSortingComparisonTable exited with code 0 after 1.3868968486785889 sec
# ================================================================================
# >> Running processor (class=GenSortingComparisonTable) ...
# ========== GenSortingComparisonTable exited with code 0 after 1.3127307891845703 sec
# ================================================================================
# >> Running processor (class=GenSortingComparisonTable) ...
# ========== GenSortingComparisonTable exited with code 0 after 1.3708162307739258 sec
# ================================================================================
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_GenSortingComparisonTablebef4d38r/json_out.json -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/KiloSort_1/sorting_comparison.json
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_GenSortingComparisonTable0a0y7te2/json_out.json -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/KiloSort_2/sorting_comparison.json
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_GenSortingComparisonTablebef4d38r/html_out.html -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/KiloSort_1/sorting_comparison.html
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_GenSortingComparisonTable0a0y7te2/html_out.html -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/KiloSort_2/sorting_comparison.html
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_GenSortingComparisonTableofhhtqsb/json_out.json -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/KiloSort_0/sorting_comparison.json
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_GenSortingComparisonTableofhhtqsb/html_out.html -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/KiloSort_0/sorting_comparison.html
# Saving result object...
# Saving result object...
# Saving result object...
# Job: GenSortingComparisonTable (version: 0.2.0)
# Timestamp: 2019-03-27 21:27:23
# Saving result object...
# Job: GenSortingComparisonTable (version: 0.2.0)
# Timestamp: 2019-03-27 21:27:23
# Job: GenSortingComparisonTable (version: 0.2.0)
# Timestamp: 2019-03-27 21:27:23
# RUNNING SHELL SCRIPT: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_GenSortingComparisonTable8wjhgova/run.sh
# Job: GenSortingComparisonTable (version: 0.2.0)
# Timestamp: 2019-03-27 21:27:23
# RUNNING SHELL SCRIPT: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_GenSortingComparisonTablen12ela8v/run.sh
# RUNNING SHELL SCRIPT: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_GenSortingComparisonTable01cdl24d/run.sh
# RUNNING SHELL SCRIPT: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_GenSortingComparisonTablei8q0_ysk/run.sh
# BATCH  running: 4 running, 4 finished, 0 errors -- 12 total jobs
# Uploading result for job 3
# Uploading result for job 2
# Uploading result for job 0
# Uploading result for job 1
# BATCH  running: 8 running, 0 finished, 0 errors -- 12 total jobs
# >> Running processor (class=GenSortingComparisonTable) ...
# ========== GenSortingComparisonTable exited with code 0 after 1.2966516017913818 sec
# ================================================================================
# >> Running processor (class=GenSortingComparisonTable) ...
# ========== GenSortingComparisonTable exited with code 0 after 1.2374346256256104 sec
# ================================================================================
# >> Running processor (class=GenSortingComparisonTable) ...
# ========== GenSortingComparisonTable exited with code 0 after 1.3002684116363525 sec
# ================================================================================
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_GenSortingComparisonTable_hh9tbxo/json_out.json -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/IronClust_static_0/sorting_comparison.json
# >> Running processor (class=GenSortingComparisonTable) ...
# ========== GenSortingComparisonTable exited with code 0 after 1.2916951179504395 sec
# ================================================================================
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_GenSortingComparisonTable_hh9tbxo/html_out.html -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/IronClust_static_0/sorting_comparison.html
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_GenSortingComparisonTable_8d_ucz7/json_out.json -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/IronClust_static_3/sorting_comparison.json
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_GenSortingComparisonTable_8d_ucz7/html_out.html -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/IronClust_static_3/sorting_comparison.html
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_GenSortingComparisonTablegyw3vfqg/json_out.json -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/IronClust_static_1/sorting_comparison.json
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_GenSortingComparisonTablegyw3vfqg/html_out.html -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/IronClust_static_1/sorting_comparison.html
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_GenSortingComparisonTablen7__ruvo/json_out.json -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/IronClust_static_2/sorting_comparison.json
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_GenSortingComparisonTablen7__ruvo/html_out.html -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/IronClust_static_2/sorting_comparison.html
# Saving result object...
# Saving result object...
# Saving result object...
# Saving result object...
# Job: GenSortingComparisonTable (version: 0.2.0)
# Timestamp: 2019-03-27 21:27:25
# Job: GenSortingComparisonTable (version: 0.2.0)
# Timestamp: 2019-03-27 21:27:25
# Job: GenSortingComparisonTable (version: 0.2.0)
# Timestamp: 2019-03-27 21:27:25
# Job: GenSortingComparisonTable (version: 0.2.0)
# Timestamp: 2019-03-27 21:27:25
# RUNNING SHELL SCRIPT: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_GenSortingComparisonTablerv0i2bsg/run.sh
# RUNNING SHELL SCRIPT: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_GenSortingComparisonTableufhryzee/run.sh
# RUNNING SHELL SCRIPT: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_GenSortingComparisonTableb8wtgf5c/run.sh
# RUNNING SHELL SCRIPT: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_GenSortingComparisonTable6narulla/run.sh
# BATCH  running: 8 running, 4 finished, 0 errors -- 12 total jobs
# >> Running processor (class=GenSortingComparisonTable) ...
# ========== GenSortingComparisonTable exited with code 0 after 1.2953557968139648 sec
# ================================================================================
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_GenSortingComparisonTablei1rihz_3/json_out.json -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/MountainSort4_2/sorting_comparison.json
# >> Running processor (class=GenSortingComparisonTable) ...
# ========== GenSortingComparisonTable exited with code 0 after 1.3477473258972168 sec
# ================================================================================
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_GenSortingComparisonTablei1rihz_3/html_out.html -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/MountainSort4_2/sorting_comparison.html
# >> Running processor (class=GenSortingComparisonTable) ...
# ========== GenSortingComparisonTable exited with code 0 after 1.342123031616211 sec
# ================================================================================
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_GenSortingComparisonTableza5rpp1h/json_out.json -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/MountainSort4_1/sorting_comparison.json
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_GenSortingComparisonTableza5rpp1h/html_out.html -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/MountainSort4_1/sorting_comparison.html
# >> Running processor (class=GenSortingComparisonTable) ...
# ========== GenSortingComparisonTable exited with code 0 after 1.4035353660583496 sec
# ================================================================================
# Uploading result for job 3
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_GenSortingComparisonTable7qxorr49/json_out.json -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/MountainSort4_3/sorting_comparison.json
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_GenSortingComparisonTable7qxorr49/html_out.html -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/MountainSort4_3/sorting_comparison.html
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_GenSortingComparisonTableunemolgr/json_out.json -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/MountainSort4_0/sorting_comparison.json
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_GenSortingComparisonTableunemolgr/html_out.html -> /home/jjun/src/spikeforest/docs/example_notebooks/sortings/example1/MountainSort4_0/sorting_comparison.html
# Uploading result for job 5
# Saving result object...
# Saving result object...
# Uploading result for job 7
# Saving result object...
# Saving result object...
# Uploading result for job 2
# Uploading result for job 6
# Uploading result for job 0
# local_resource_IomBIS: Saving/uploading outputs: batch_1553736440.9802465_IuU8oX
# Uploading result for job 8
# Saving/uploading json_out for result 2 of 12: sha1://6474d80c7712e72e9fa67dc277e2e9fa25a76287/sorting_comparison.json...
# Saving/uploading json_out for result 1 of 12: sha1://aa52099075cb9754d0d2683d2ec37c1ce99f3eeb/sorting_comparison.json...
# Saving/uploading json_out for result 0 of 12: sha1://75fa04f61d0aa302524f4224a148588088a5da5b/sorting_comparison.json...
# Saving/uploading json_out for result 3 of 12: sha1://56826a5180955a5a1e5f5232c08b34076b6ced9b/sorting_comparison.json...
# Saving/uploading json_out for result 5 of 12: sha1://dce134c8bbb2224cbdb08750efe10953d55c8037/sorting_comparison.json...
# Saving/uploading json_out for result 6 of 12: sha1://dce134c8bbb2224cbdb08750efe10953d55c8037/sorting_comparison.json...
# Saving/uploading json_out for result 4 of 12: sha1://dce134c8bbb2224cbdb08750efe10953d55c8037/sorting_comparison.json...
# Saving/uploading json_out for result 11 of 12: sha1://87e34222a0c941fca7c54c661ab4b5bfaaa85cda/sorting_comparison.json...
# Saving/uploading json_out for result 10 of 12: sha1://de3d4bea37cadf250ffeb1b3882e0f25a1a87d7c/sorting_comparison.json...
# Saving/uploading json_out for result 8 of 12: sha1://c339af0fc322bfb2ec21d0a422c58055f152350e/sorting_comparison.json...
# BATCH  running: 0 running, 12 finished, 0 errors -- 12 total jobs
# Saving/uploading json_out for result 7 of 12: sha1://dce134c8bbb2224cbdb08750efe10953d55c8037/sorting_comparison.json...
# Saving/uploading json_out for result 9 of 12: sha1://c37da6a23ea802a2c8562abf53ab69490370c199/sorting_comparison.json...
# Saving/uploading html_out for result 2 of 12: sha1://476a49c8ebfb94c409b76f7d453328e7b5dd1dbd/sorting_comparison.html...
# Uploading result for job 1
# Saving/uploading html_out for result 1 of 12: sha1://89a812a9ba04a28f1ce1fae9a2b93110284c8381/sorting_comparison.html...
# Saving/uploading html_out for result 3 of 12: sha1://db074d9f72a4514d1203bfe01a844989013068d7/sorting_comparison.html...
# Saving/uploading html_out for result 11 of 12: sha1://1ae729801b283f46a08b4d2df2c6a532a08a9346/sorting_comparison.html...
# Saving/uploading html_out for result 0 of 12: sha1://2af761cbfabd53e569c58ff45de621ffe78f6b85/sorting_comparison.html...
# Saving/uploading html_out for result 4 of 12: sha1://e6dbcd0971b70dadcae819889de77a26152c6723/sorting_comparison.html...
# Saving/uploading html_out for result 10 of 12: sha1://5e54b22a925fff4688401645d2494183f37c7b16/sorting_comparison.html...
# Saving/uploading html_out for result 8 of 12: sha1://773c40c8c426654033c47aacd4f77d8faeb67ae0/sorting_comparison.html...
# Saving/uploading html_out for result 9 of 12: sha1://e4a05711114bffedb109ecd3d986d1778f8d6ae1/sorting_comparison.html...
# Saving/uploading html_out for result 7 of 12: sha1://e6dbcd0971b70dadcae819889de77a26152c6723/sorting_comparison.html...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading html_out for result 6 of 12: sha1://e6dbcd0971b70dadcae819889de77a26152c6723/sorting_comparison.html...
# Saving/uploading console output...
# Uploading result for job 4
# Saving/uploading html_out for result 5 of 12: sha1://e6dbcd0971b70dadcae819889de77a26152c6723/sorting_comparison.html...
# Saving/uploading console output...
# saving-outputs
# local_resource_IomBIS: Saving/uploading results: batch_1553736440.9802465_IuU8oX
# finalizing-job-statuses
# local_resource_IomBIS: No batches pending.
# Batch is finished.
# Stopping local compute resource
# Exiting compute resource...
# .
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-92f28c95953c> in <module>
#      62         L_precision1 = [1-x for x in df1.transpose()['f_p'].to_list()]
#      63         L_snr.append(L_snr1)
# ---> 64         L_recall.append(L_recall1)
#      65         L_precision.append(L_precision1)
#      66     D_comparison1 = dict(
#
# NameError: name 'L_recall' is not defined

# %%
# assemble comparison objects
LD_comparison = list()
for S_sorter1 in D_params['sorter']:
    L_snr = list()
    L_accuracy = list()
    L_precision = list()
    L_recall = list()
    for iJob in range(nJobs):
        path_out1 = '{}_{}'.format(os.path.join(path_out, S_sorter1), iJob)
        path_out_json1 = os.path.join(path_out1, 'sorting_comparison.json')
        df1 = pd.read_json(path_or_buf=path_out_json1)    
        L_unit_id = [int(x) for x in df1.transpose()['unit_id'].to_list()]
        L_accuracy1 = df1.transpose()['accuracy'].to_list()
        L_snr1 = sx_true.getUnitsProperty(unit_ids=L_unit_id, property_name='snr')
        L_recall1 = [1-x for x in df1.transpose()['f_n'].to_list()]
        L_precision1 = [1-x for x in df1.transpose()['f_p'].to_list()]
        L_snr.append(L_snr1)  
        L_accuracy.append(L_accuracy1)
        L_recall.append(L_recall1)
        L_precision.append(L_precision1)
    D_comparison1 = dict(
        L_snr = L_snr, S_sorter=S_sorter1, 
        L_accuracy = L_accuracy, L_recall = L_recall, L_precision = L_precision)
    LD_comparison.append(D_comparison1)
    
dt = datetime.datetime.now() - t1
print('took {:0.3f}s'.format(dt.total_seconds()))
# Out:
# took 805.711s

# %%
# plot SNR vs accuracy for the first sorting output
accuracy_thresh, snr_thresh = .8, 8

#LD_comparison1 = [LD_comparison[i] for i in [3,1,4,0,2]]
LD_comparison1 = LD_comparison
for D_comparison1 in LD_comparison1:
    fig=plt.figure(figsize=(12,3))
    L_accuracy1 = D_comparison1['L_accuracy']
    L_recall1 = D_comparison1['L_recall']
    L_precision1 = D_comparison1['L_precision']
    L_snr1 = D_comparison1['L_snr']
    S_sorter1 = D_comparison1['S_sorter']
    
    print(S_sorter1)
    ax=fig.add_subplot(1,3,1)
    ax.plot(L_snr, L_accuracy1, '.')
    plt.xlabel('SNR')
    plt.ylabel('accuracy')    
    plt.ylim(0,1)
    nUnits_above = np.sum(np.array(L_accuracy1) >= accuracy_thresh)
    plt.title('{} units > {} accuracy'.format(nUnits_above, accuracy_thresh))  
    
    ax=fig.add_subplot(1,3,2)
    ax.plot(L_snr, L_recall1, '.')
    plt.xlabel('SNR')
    plt.ylabel('recall')    
    plt.ylim(0,1)
    nUnits_above = np.sum(np.array(L_recall1) >= accuracy_thresh)
    plt.title('{} units > {} recall'.format(nUnits_above, accuracy_thresh))  
    
    ax=fig.add_subplot(1,3,3)
    ax.plot(L_snr, L_precision1, '.')
    plt.xlabel('SNR')
    plt.ylabel('precision')    
    plt.ylim(0,1)
    nUnits_above = np.sum(np.array(L_precision1) >= accuracy_thresh)
    plt.title('{} units > {} precision'.format(nUnits_above, accuracy_thresh))  
    
    plt.show()
# Out:
# KiloSort
# IronClust_static
# MountainSort4
