# %%
# This example runs multiple sorters in parallel using remote cluster (srun)
# Created by James Jun on Mar 28, 2019

# prerequisits
# slurm
# $ pip install ml_ms4alg
# $ conda install -c conda-forge ipywidgets
# $ jupyter labextension install @jupyter-widgets/jupyterlab-manager

# please ignore the warning when running MountainSort4
#   RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import spikeforest_analysis as sa
from spikeforest import spikeextractors as se
import os, shutil, datetime, json, numpy as np, pandas as pd, json, datetime
import sfdata as sf
from spikesorters import IronClust, MountainSort4, KiloSort, KiloSort2
from spikeforest import spiketoolkit as st
from spikeforest import spikewidgets as sw
import ipywidgets as widgets
from spikeforest_analysis.compare_sortings_with_truth import GenSortingComparisonTable
from spikeforest_analysis.compute_units_info import ComputeUnitsInfo
from matplotlib import pyplot as plt
import mlprocessors as mlpr
from mlprocessors import LocalComputeResource

# %%
# Define sorters
# run `createJob` instead of `execute` for delayed execution

f_force_run = True
adjacency_radius = 100

def irc_static(recpath, firings_out):
    return IronClust.createJob(
            recording_dir=recpath,
            firings_out=firings_out,
            detect_sign=-1,
            adjacency_radius=adjacency_radius,
            prm_template_name='static',
            _force_run=f_force_run)

def irc_drift(recpath, firings_out):
    return IronClust.createJob(
            recording_dir=recpath,
            firings_out=firings_out,
            detect_sign=-1,
            adjacency_radius=adjacency_radius,
            prm_template_name='drift',
            _force_run=f_force_run)

def ms4(recpath, firings_out):
    return MountainSort4.createJob(
            recording_dir=recpath,
            firings_out=firings_out,
            detect_sign=-1,
            adjacency_radius=adjacency_radius,
            _force_run=f_force_run)

def ksort(recpath, firings_out):
    return KiloSort.createJob(
            recording_dir=recpath,
            firings_out=firings_out,
            detect_sign=-1,
            adjacency_radius=adjacency_radius,
            _force_run=f_force_run)

def ksort2(recpath, firings_out):
    return KiloSort2.createJob(
            recording_dir=recpath,
            firings_out=firings_out,
            detect_sign=-1,
            adjacency_radius=adjacency_radius,
            _force_run=f_force_run)

#D_sorters = dict(KiloSort=ksort, IronClust_static=irc, MountainSort4=ms4, KiloSort2=ksort2, IronClust_drift=irc_drift)
D_sorters = dict(KiloSort=ksort, IronClust_static=irc_static, MountainSort4=ms4)

# %%
# select a data source and sorter
# you may change the data source index and sorter index
LS_sorter = list(D_sorters.keys())
LS_sorter.insert(0,'all')

widget1 = widgets.Dropdown(
    options=LS_sorter, index=0, description='Spike sorters')
display(widget1)

LS_datasource = ['generate locally', 'download']
widget2 = widgets.Dropdown(
    options = LS_datasource, index=0, description='Data source')
display(widget2)
# Out:
# Dropdown(description='Spike sorters', options=('all', 'KiloSort', 'IronClust_static', 'MountainSort4'), value=…
# Dropdown(description='Data source', options=('generate locally', 'download'), value='generate locally')

# %%
# create a parameters dictionary
D_params = dict(
    datasource = LS_datasource[widget2.index],
    path_in = '/mnt/ceph/users/jjun/temp/recordings/example1',
    path_out = '/mnt/ceph/users/jjun/temp/sortings/example1',
    num_repeat = 4
    )

S_sorter = LS_sorter[widget1.index]
if S_sorter == 'all':
    D_params['sorter'] = LS_sorter[1:]
    
else:
    D_params['sorter'] = [S_sorter]

# %%
# get recording
path_in = D_params['path_in']
# delete previous recording
#  os.path.exists(recpath): shutil.rmtree(recpath)
# delete previous output and make save
path_in_true = os.path.join(path_in, 'firings_true.mda')
path_in_json = os.path.join(path_in, 'units_info.json')

if D_params['datasource'] == 'generate locally':
    print(path_in_true)
    if not os.path.exists(path_in_true):
        # generate recording
        rx, sx_true = se.example_datasets.toy_example1(
            duration=600, num_channels=4, samplerate=30000, K=10)
        print('Generated recording in ' + path_in)
    else:
        rx = se.MdaRecordingExtractor(path_in)
        sx_true = se.MdaSortingExtractor(path_in_true)
        print('Using cached recording in ' + path_in)
else:
    # download recording
    #kpath = 'kbucket://15734439d8cf/groundtruth/magland_synth/datasets_noise10_K10_C4/001_synth'
    #kpath = '/mnt/home/jjun/ceph/groundtruth/hybrid_drift/rec_32c_600s_11'
    kpath = '/mnt/home/jjun/ceph/groundtruth/hybrid_drift/rec_64c_1200s_11'
    rx = se.MdaRecordingExtractor(kpath, download=True)
    sx_true = se.MdaSortingExtractor(kpath + '/firings_true.mda')   
    
if not os.path.exists(path_in): 
    os.makedirs(path_in)
    se.MdaRecordingExtractor.writeRecording(recording=rx, save_path=path_in)
    se.MdaSortingExtractor.writeSorting(
        sorting=sx_true, save_path=path_in_true)
        
# summarize recording
if not os.path.exists(path_in_json):
    ComputeUnitsInfo.execute(
        recording_dir = path_in,
        firings = path_in_true,
        json_out = path_in_json,
        )
with open(path_in_json) as f:
    snr_json = json.load(f)
    unit_snrs = [x['snr'] for x in snr_json]
    unit_ids = [x['unit_id'] for x in snr_json]
    sx_true.setUnitsProperty(property_name='snr', 
         values=unit_snrs, unit_ids=unit_ids)
# Out:
# /mnt/ceph/users/jjun/temp/recordings/example1/firings_true.mda
# Generated recording in /mnt/ceph/users/jjun/temp/recordings/example1
# Preparing 1 local file inputs
# Preparing 1 local directory inputs
# Computing output signatures...
# .
# Job: ComputeUnitsInfo (version: 0.1.8)
# Timestamp: 2019-03-28 09:45:37
# Running processor directly...
# Saving output: /mnt/ceph/users/jjun/sha1-cache/tmp/tmp_execute_outputdir_ComputeUnitsInfo919f2ni2/json_out.json -> /mnt/ceph/users/jjun/temp/recordings/example1/units_info.json

# %%
t1 = datetime.datetime.now()
#D_compute = dict(srun_opts='-c 2 -n 80 -p ccm', num_parallel=4)
D_compute = dict(srun_opts='-n 1 -c 8 -p gpu --gres=gpu:1 --constraint=v100', num_parallel=6)

# Schedule spike sorting tasks
path_in = D_params['path_in']
path_out = D_params['path_out']
nJobs = D_params['num_repeat']
L_jobs_sorting = list()
for S_sorter1 in D_params['sorter']:
    for iJob in range(nJobs):
        path_out1 = '{}_{}'.format(os.path.join(path_out, S_sorter1), iJob)
        if not os.path.exists(path_out1): 
            os.makedirs(path_out1)  
        path_out_firings1 = os.path.join(path_out1, 'firings_out.mda')
        if not os.path.exists(path_out_firings1):
            print('Running '+ S_sorter1 + ' in notebook.')
            L_jobs_sorting.append(D_sorters[S_sorter1](path_in, path_out_firings1))   
        
# Run sorting jobs
with LocalComputeResource(**D_compute) as compute_resource:
    mlpr.executeBatch(jobs=L_jobs_sorting, compute_resource=compute_resource)
        
# Collect results and run validation
L_jobs_comparison = list()
for S_sorter1 in D_params['sorter']:
    for iJob in range(nJobs):
        path_out1 = '{}_{}'.format(os.path.join(path_out, S_sorter1), iJob)
        path_out_firings1 = os.path.join(path_out1, 'firings_out.mda')
        sx1 = se.MdaSortingExtractor(path_out_firings1)
        print('Loaded '+ S_sorter1 + ' from ' + path_out_firings1)
    
        # validation           
        path_out_json1 = os.path.join(path_out1, 'sorting_comparison.json')
        if not os.path.exists(path_out_json1):
            print('Computing comparison...')
            job1 = GenSortingComparisonTable.createJob(
                firings = path_out_firings1,
                units_true = None,
                firings_true = os.path.join(path_in, 'firings_true.mda'),
                json_out = path_out_json1,
                html_out = os.path.join(path_out1, 'sorting_comparison.html'),
                )
            L_jobs_comparison.append(job1)

# Run comparison jobs
with LocalComputeResource(**D_compute) as compute_resource:
    mlpr.executeBatch(jobs=L_jobs_comparison, compute_resource=compute_resource)

# assemble comparison objects
LD_comparison = list()
for S_sorter1 in D_params['sorter']:
    L_snr = list()
    L_accuracy = list()
    L_precision = list()
    L_recall = list()
    for iJob in range(nJobs):
        path_out1 = '{}_{}'.format(os.path.join(path_out, S_sorter1), iJob)
        path_out_json1 = os.path.join(path_out1, 'sorting_comparison.json')
        df1 = pd.read_json(path_or_buf=path_out_json1)    
        L_unit_id = [int(x) for x in df1.transpose()['unit_id'].to_list()]
        L_accuracy1 = df1.transpose()['accuracy'].to_list()
        L_snr1 = sx_true.getUnitsProperty(unit_ids=L_unit_id, property_name='snr')
        L_recall1 = [1-x for x in df1.transpose()['f_n'].to_list()]
        L_precision1 = [1-x for x in df1.transpose()['f_p'].to_list()]
        L_snr.append(L_snr1)  
        L_accuracy.append(L_accuracy1)
        L_recall.append(L_recall1)
        L_precision.append(L_precision1)
    D_comparison1 = dict(
        L_snr = L_snr, S_sorter=S_sorter1, 
        L_accuracy = L_accuracy, L_recall = L_recall, L_precision = L_precision)
    LD_comparison.append(D_comparison1)
    
dt = datetime.datetime.now() - t1
print('took {:0.3f}s'.format(dt.total_seconds()))
# Out:
# Running KiloSort in notebook.
# Preparing 1 local directory inputs
# Computing output signatures...
# .
# Running KiloSort in notebook.
# Preparing 1 local directory inputs
# Computing output signatures...
# .
# Running KiloSort in notebook.
# Preparing 1 local directory inputs
# Computing output signatures...
# .
# Running KiloSort in notebook.
# Preparing 1 local directory inputs
# Computing output signatures...
# .
# Running IronClust_static in notebook.
# Preparing 1 local directory inputs
# Computing output signatures...
# .
# Running IronClust_static in notebook.
# Preparing 1 local directory inputs
# Computing output signatures...
# .
# Running IronClust_static in notebook.
# Preparing 1 local directory inputs
# Computing output signatures...
# .
# Running IronClust_static in notebook.
# Preparing 1 local directory inputs
# Computing output signatures...
# .
# Running MountainSort4 in notebook.
# Preparing 1 local directory inputs
# Computing output signatures...
# .
# Running MountainSort4 in notebook.
# Preparing 1 local directory inputs
# Computing output signatures...
# .
# Running MountainSort4 in notebook.
# Preparing 1 local directory inputs
# Computing output signatures...
# .
# Running MountainSort4 in notebook.
# Preparing 1 local directory inputs
# Computing output signatures...
# .
# Checking for cached results prior to sending to compute resource...
# MOUNTAIN CONFIG: local database; local sha-1 cache
# registering compute resource:  local_resource_vTgRGx
# local_resource_vTgRGx: Starting compute resource: local_resource_vTgRGx
# local_resource_vTgRGx: No batches pending.
# Ensuring files are available on remote server...
# MOUNTAIN CONFIG: local database; local sha-1 cache
# Waiting for batch to start on compute resource: local_resource_vTgRGx
# local_resource_vTgRGx: Starting batch: batch_1553780989.0125346_VjY5J1
# local_resource_vTgRGx: Loading batch: batch_1553780989.0125346_VjY5J1
# local_resource_vTgRGx: Starting batch: batch_1553780989.0125346_VjY5J1
# Checking for cached results prior to using srun...
# Making sure files are available on local computer...
# Realizing sha1://4d32ddfa8a0aeef6cd18e44dc5004c4ccec59df8/object.json...
# Realizing sha1://f07e27f85a572b800372ee0274ab4102a375fba8/object.json...
# Realizing sha1://aac3ff05a8bf05ef1515e29799045a5e645ecc4c/object.json...
# USING SRUN OPTS: -n 1 -c 8 -p gpu --gres=gpu:1 --constraint=v100
# USING NUM SIMULTANEOUS SRUN CALLS: 6
# RUNNING SHELL SCRIPT: /tmp/tmp_shellscripteb2ghdru/script.sh
# RUNNING SHELL SCRIPT: /tmp/tmp_shellscriptdtvf2ylx/script.sh
# RUNNING SHELL SCRIPT: /tmp/tmp_shellscripth2n7qb4s/script.sh
# RUNNING SHELL SCRIPT: /tmp/tmp_shellscripto_30dihz/script.sh
# RUNNING SHELL SCRIPT: /tmp/tmp_shellscriptycoq0256/script.sh
# RUNNING SHELL SCRIPT: /tmp/tmp_shellscript5c_2tvtx/script.sh
# BATCH  running: 1 running, 0 finished, 0 errors -- 12 total jobs
# BATCH  running: 0 running, 0 finished, 0 errors -- 12 total jobs
# BATCH  running: 6 running, 0 finished, 0 errors -- 12 total jobs
# BATCH  running: 12 running, 0 finished, 0 errors -- 12 total jobs
# BATCH  running: 10 running, 2 finished, 0 errors -- 12 total jobs
# Uploading result for job 5
# Uploading result for job 4
# Uploading result for job 1
# BATCH  running: 9 running, 3 finished, 0 errors -- 12 total jobs
# Uploading result for job 0
# BATCH  running: 7 running, 5 finished, 0 errors -- 12 total jobs
# Uploading result for job 2
# Uploading result for job 3
# BATCH  running: 6 running, 6 finished, 0 errors -- 12 total jobs
# Uploading result for job 6
# BATCH  running: 4 running, 8 finished, 0 errors -- 12 total jobs
# Uploading result for job 7
# Uploading result for job 10
# Uploading result for job 9
# BATCH  running: 2 running, 10 finished, 0 errors -- 12 total jobs
# BATCH  running: 1 running, 11 finished, 0 errors -- 12 total jobs
# Uploading result for job 11
# Loading result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553780989.0125346_VjY5J1'} 0
# Loaded result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553780989.0125346_VjY5J1'} 0
# Loading result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553780989.0125346_VjY5J1'} 1
# Loaded result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553780989.0125346_VjY5J1'} 1
# Loading result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553780989.0125346_VjY5J1'} 2
# Loaded result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553780989.0125346_VjY5J1'} 2
# Loading result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553780989.0125346_VjY5J1'} 3
# Loaded result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553780989.0125346_VjY5J1'} 3
# Loading result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553780989.0125346_VjY5J1'} 4
# Loaded result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553780989.0125346_VjY5J1'} 4
# Loading result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553780989.0125346_VjY5J1'} 5
# Loaded result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553780989.0125346_VjY5J1'} 5
# Loading result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553780989.0125346_VjY5J1'} 6
# Loaded result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553780989.0125346_VjY5J1'} 6
# Loading result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553780989.0125346_VjY5J1'} 7
# Loaded result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553780989.0125346_VjY5J1'} 7
# Loading result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553780989.0125346_VjY5J1'} 8
# Loaded result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553780989.0125346_VjY5J1'} 8
# Loading result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553780989.0125346_VjY5J1'} 9
# BATCH  running: 0 running, 12 finished, 0 errors -- 12 total jobs
# Loaded result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553780989.0125346_VjY5J1'} 9
# Loading result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553780989.0125346_VjY5J1'} 10
# Loaded result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553780989.0125346_VjY5J1'} 10
# Loading result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553780989.0125346_VjY5J1'} 11
# Loaded result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553780989.0125346_VjY5J1'} 11
# local_resource_vTgRGx: Saving/uploading outputs: batch_1553780989.0125346_VjY5J1
# Stopping job monitor because batch status is: saving-outputs
# Saving/uploading firings_out for result 0 of 12: sha1://628f8f793d6580bd54bb345b4ba991ebab70f824/firings_out.mda...
# Saving/uploading firings_out for result 2 of 12: sha1://a4ee867c8eaf9ac09843eb76378f0e3e45bb29cc/firings_out.mda...
# Saving/uploading firings_out for result 1 of 12: sha1://8369e7eec68952484236996e82265dbb334004f3/firings_out.mda...
# Saving/uploading firings_out for result 3 of 12: sha1://9a9e2243662bc2d0200b23a0d64eac0404d11161/firings_out.mda...
# Saving/uploading firings_out for result 4 of 12: sha1://7fccea4b0c6423dbf1232944a8522baf51987f50/firings_out.mda...
# Saving/uploading firings_out for result 5 of 12: sha1://7fccea4b0c6423dbf1232944a8522baf51987f50/firings_out.mda...
# Saving/uploading firings_out for result 6 of 12: sha1://7fccea4b0c6423dbf1232944a8522baf51987f50/firings_out.mda...
# Saving/uploading firings_out for result 11 of 12: sha1://b7542830535e194881dff699b180aa19fec4656a/firings_out.mda...
# Saving/uploading firings_out for result 7 of 12: sha1://7fccea4b0c6423dbf1232944a8522baf51987f50/firings_out.mda...
# Saving/uploading firings_out for result 10 of 12: sha1://79d9d73d2772edce15a7b10360827a28b4484d8d/firings_out.mda...
# Saving/uploading firings_out for result 8 of 12: sha1://08a12f983f04da5df6631f803f5f491aa5ef2637/firings_out.mda...
# Saving/uploading firings_out for result 9 of 12: sha1://2b3972c0e4eb44afd104bae16fa5059718c56721/firings_out.mda...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading console output...
# local_resource_vTgRGx: Saving/uploading results: batch_1553780989.0125346_VjY5J1
# finalizing-job-statuses
# local_resource_vTgRGx: No batches pending.
# Batch is finished.
# Exiting compute resource...
# Stopping local compute resource
# .
# Loaded KiloSort from /mnt/ceph/users/jjun/temp/sortings/example1/KiloSort_0/firings_out.mda
# Computing comparison...
# Preparing 2 local file inputs
# Computing output signatures...
# .
# Loaded KiloSort from /mnt/ceph/users/jjun/temp/sortings/example1/KiloSort_1/firings_out.mda
# Computing comparison...
# Preparing 2 local file inputs
# Computing output signatures...
# .
# Loaded KiloSort from /mnt/ceph/users/jjun/temp/sortings/example1/KiloSort_2/firings_out.mda
# Computing comparison...
# Preparing 2 local file inputs
# Computing output signatures...
# .
# Loaded KiloSort from /mnt/ceph/users/jjun/temp/sortings/example1/KiloSort_3/firings_out.mda
# Computing comparison...
# Preparing 2 local file inputs
# Computing output signatures...
# .
# Loaded IronClust_static from /mnt/ceph/users/jjun/temp/sortings/example1/IronClust_static_0/firings_out.mda
# Computing comparison...
# Preparing 2 local file inputs
# Computing output signatures...
# .
# Loaded IronClust_static from /mnt/ceph/users/jjun/temp/sortings/example1/IronClust_static_1/firings_out.mda
# Computing comparison...
# Preparing 2 local file inputs
# Computing output signatures...
# .
# Loaded IronClust_static from /mnt/ceph/users/jjun/temp/sortings/example1/IronClust_static_2/firings_out.mda
# Computing comparison...
# Preparing 2 local file inputs
# Computing output signatures...
# .
# Loaded IronClust_static from /mnt/ceph/users/jjun/temp/sortings/example1/IronClust_static_3/firings_out.mda
# Computing comparison...
# Preparing 2 local file inputs
# Computing output signatures...
# .
# Loaded MountainSort4 from /mnt/ceph/users/jjun/temp/sortings/example1/MountainSort4_0/firings_out.mda
# Computing comparison...
# Preparing 2 local file inputs
# Computing output signatures...
# .
# Loaded MountainSort4 from /mnt/ceph/users/jjun/temp/sortings/example1/MountainSort4_1/firings_out.mda
# Computing comparison...
# Preparing 2 local file inputs
# Computing output signatures...
# .
# Loaded MountainSort4 from /mnt/ceph/users/jjun/temp/sortings/example1/MountainSort4_2/firings_out.mda
# Computing comparison...
# Preparing 2 local file inputs
# Computing output signatures...
# .
# Loaded MountainSort4 from /mnt/ceph/users/jjun/temp/sortings/example1/MountainSort4_3/firings_out.mda
# Computing comparison...
# Preparing 2 local file inputs
# Computing output signatures...
# .
# Checking for cached results prior to sending to compute resource...
# MOUNTAIN CONFIG: local database; local sha-1 cache
# registering compute resource:  local_resource_vYZnLj
# local_resource_vYZnLj: Starting compute resource: local_resource_vYZnLj
# local_resource_vYZnLj: No batches pending.
# Ensuring files are available on remote server...
# MOUNTAIN CONFIG: local database; local sha-1 cache
# Waiting for batch to start on compute resource: local_resource_vYZnLj
# local_resource_vYZnLj: Starting batch: batch_1553781074.226559_2aPBcd
# local_resource_vYZnLj: Loading batch: batch_1553781074.226559_2aPBcd
# local_resource_vYZnLj: Starting batch: batch_1553781074.226559_2aPBcd
# Checking for cached results prior to using srun...
# Making sure files are available on local computer...
# Realizing sha1://79d9d73d2772edce15a7b10360827a28b4484d8d/firings_out.mda...
# Realizing sha1://a4ee867c8eaf9ac09843eb76378f0e3e45bb29cc/firings_out.mda...
# Realizing sha1://1afff1f4c38ce6ae246e33c8dd6558ccac8faf97/object.json...
# Realizing sha1://9a9e2243662bc2d0200b23a0d64eac0404d11161/firings_out.mda...
# Realizing sha1://2b3972c0e4eb44afd104bae16fa5059718c56721/firings_out.mda...
# Realizing sha1://7fccea4b0c6423dbf1232944a8522baf51987f50/firings_out.mda...
# Realizing sha1://b7542830535e194881dff699b180aa19fec4656a/firings_out.mda...
# Realizing sha1://628f8f793d6580bd54bb345b4ba991ebab70f824/firings_out.mda...
# BATCH  running: 0 running, 0 finished, 0 errors -- 12 total jobs
# Realizing sha1://88dd27ff68b2b09ff4f04c36afd75949bf31b6f0/firings_true.mda...
# Realizing sha1://8369e7eec68952484236996e82265dbb334004f3/firings_out.mda...
# Realizing sha1://08a12f983f04da5df6631f803f5f491aa5ef2637/firings_out.mda...
# USING SRUN OPTS: -n 1 -c 8 -p gpu --gres=gpu:1 --constraint=v100
# USING NUM SIMULTANEOUS SRUN CALLS: 6
# RUNNING SHELL SCRIPT: /tmp/tmp_shellscriptzhs8bgb4/script.sh
# RUNNING SHELL SCRIPT: /tmp/tmp_shellscripta8b0l8x3/script.sh
# RUNNING SHELL SCRIPT: /tmp/tmp_shellscript1y97cj8x/script.sh
# RUNNING SHELL SCRIPT: /tmp/tmp_shellscript79zj1e28/script.sh
# RUNNING SHELL SCRIPT: /tmp/tmp_shellscript0f_cbkpf/script.sh
# RUNNING SHELL SCRIPT: /tmp/tmp_shellscripthjdw9e93/script.sh
# BATCH  running: 6 running, 0 finished, 0 errors -- 12 total jobs
# BATCH  running: 12 running, 0 finished, 0 errors -- 12 total jobs
# BATCH  running: 4 running, 8 finished, 0 errors -- 12 total jobs
# Loading result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553781074.226559_2aPBcd'} 0
# Loaded result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553781074.226559_2aPBcd'} 0
# Loading result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553781074.226559_2aPBcd'} 1
# Uploading result for job 3
# Loaded result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553781074.226559_2aPBcd'} 1
# Loading result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553781074.226559_2aPBcd'} 2
# Loaded result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553781074.226559_2aPBcd'} 2
# Loading result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553781074.226559_2aPBcd'} 3
# BATCH  running: 0 running, 12 finished, 0 errors -- 12 total jobs
# Loaded result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553781074.226559_2aPBcd'} 3
# Loading result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553781074.226559_2aPBcd'} 4
# Loaded result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553781074.226559_2aPBcd'} 4
# Loading result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553781074.226559_2aPBcd'} 5
# Uploading result for job 10
# Loaded result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553781074.226559_2aPBcd'} 5
# Loading result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553781074.226559_2aPBcd'} 6
# Loaded result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553781074.226559_2aPBcd'} 6
# Loading result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553781074.226559_2aPBcd'} 7
# Loaded result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553781074.226559_2aPBcd'} 7
# Loading result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553781074.226559_2aPBcd'} 8
# Loaded result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553781074.226559_2aPBcd'} 8
# Loading result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553781074.226559_2aPBcd'} 9
# Loaded result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553781074.226559_2aPBcd'} 9
# Loading result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553781074.226559_2aPBcd'} 10
# Loaded result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553781074.226559_2aPBcd'} 10
# Loading result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553781074.226559_2aPBcd'} 11
# Loaded result object... {'name': 'compute_resource_batch_job_results', 'batch_id': 'batch_1553781074.226559_2aPBcd'} 11
# local_resource_vYZnLj: Saving/uploading outputs: batch_1553781074.226559_2aPBcd
# Uploading result for job 9
# Saving/uploading json_out for result 0 of 12: sha1://96bfce4a5dfddde67b01a0c8a6396056c0a02aac/sorting_comparison.json...
# Saving/uploading json_out for result 1 of 12: sha1://96bfce4a5dfddde67b01a0c8a6396056c0a02aac/sorting_comparison.json...
# Saving/uploading json_out for result 5 of 12: sha1://7ee16ac34e207f2f911cbfa7c729245099e733a7/sorting_comparison.json...
# Saving/uploading json_out for result 6 of 12: /mnt/ceph/users/jjun/temp/sortings/example1/IronClust_static_2/sorting_comparison.json...
# Saving/uploading json_out for result 4 of 12: sha1://7ee16ac34e207f2f911cbfa7c729245099e733a7/sorting_comparison.json...
# Saving/uploading json_out for result 3 of 12: sha1://ae8a99d1565acd8a580be89708f7336f5b182f6d/sorting_comparison.json...
# Saving/uploading json_out for result 2 of 12: sha1://96bfce4a5dfddde67b01a0c8a6396056c0a02aac/sorting_comparison.json...
# Saving/uploading json_out for result 11 of 12: sha1://2d0eb0d3858771ba7d655efc1070478b1a8dd16e/sorting_comparison.json...
# Saving/uploading json_out for result 7 of 12: /mnt/ceph/users/jjun/temp/sortings/example1/IronClust_static_3/sorting_comparison.json...
# Saving/uploading json_out for result 9 of 12: sha1://62918ef1ca83d31d4f34fc0f5e542065347b2f18/sorting_comparison.json...
# Saving/uploading json_out for result 10 of 12: sha1://7fbb1a5967a75a7bbd47fc89d2b3a8c51530f842/sorting_comparison.json...
# Saving/uploading json_out for result 8 of 12: sha1://b1748dcf9cc3a6dd8795e915e9269f8ea32b530a/sorting_comparison.json...
# Saving/uploading html_out for result 4 of 12: sha1://d714c5cdd9a9746bc97935635d00769103cee9dc/sorting_comparison.html...
# Saving/uploading console output...
# Saving/uploading html_out for result 2 of 12: sha1://6dbb709465c7fba21a56d9dc67ae7d3524158891/sorting_comparison.html...
# Saving/uploading html_out for result 6 of 12: /mnt/ceph/users/jjun/temp/sortings/example1/IronClust_static_2/sorting_comparison.html...
# Saving/uploading html_out for result 9 of 12: sha1://5b4ca842aa0aaa9d70d35377ebb7f413700d04a4/sorting_comparison.html...
# Saving/uploading html_out for result 3 of 12: sha1://21a53d2a316dfb1130f44d6f16c9e939af7c85ef/sorting_comparison.html...
# Saving/uploading html_out for result 11 of 12: sha1://1aa61152b98aa40ee7e943e7317b63fa24278a42/sorting_comparison.html...
# Saving/uploading html_out for result 8 of 12: sha1://74242b1ffe0d3d96dc7b220e49fd6a36ba516e09/sorting_comparison.html...
# Saving/uploading html_out for result 10 of 12: sha1://2ab01bbaf3a329f14625ca734e8707f89c8dbf62/sorting_comparison.html...
# Uploading result for job 5
# Saving/uploading html_out for result 5 of 12: sha1://d714c5cdd9a9746bc97935635d00769103cee9dc/sorting_comparison.html...
# Saving/uploading html_out for result 0 of 12: sha1://6dbb709465c7fba21a56d9dc67ae7d3524158891/sorting_comparison.html...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading html_out for result 7 of 12: /mnt/ceph/users/jjun/temp/sortings/example1/IronClust_static_3/sorting_comparison.html...
# Saving/uploading html_out for result 1 of 12: sha1://6dbb709465c7fba21a56d9dc67ae7d3524158891/sorting_comparison.html...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading console output...
# Saving/uploading console output...
# Uploading result for job 7
# Uploading result for job 11
# local_resource_vYZnLj: Saving/uploading results: batch_1553781074.226559_2aPBcd
# Uploading result for job 2
# saving-results
# finalizing-job-statuses
# Batch is finished.
# local_resource_vYZnLj: No batches pending.
# Stopping local compute resource
# Exiting compute resource...
# .
# took 100.074s

# %%
#%%bash 
#rm -fr /mnt/ceph/users/jjun/temp/sortings/

# %%
# plot SNR vs accuracy for the first sorting output
accuracy_thresh, snr_thresh = .8, 8

#LD_comparison1 = [LD_comparison[i] for i in [3,1,4,0,2]]
LD_comparison1 = LD_comparison
for D_comparison1 in LD_comparison1:
    fig=plt.figure(figsize=(12,3))
    L_accuracy1 = D_comparison1['L_accuracy']
    L_recall1 = D_comparison1['L_recall']
    L_precision1 = D_comparison1['L_precision']
    L_snr1 = D_comparison1['L_snr']
    S_sorter1 = D_comparison1['S_sorter']
    
    print(S_sorter1)
    ax=fig.add_subplot(1,3,1)
    ax.plot(L_snr, L_accuracy1, '.')
    plt.xlabel('SNR')
    plt.ylabel('accuracy')    
    plt.ylim(0,1)
    nUnits_above = np.sum(np.array(L_accuracy1) >= accuracy_thresh)
    plt.title('{} units > {} accuracy'.format(nUnits_above, accuracy_thresh))  
    
    ax=fig.add_subplot(1,3,2)
    ax.plot(L_snr, L_recall1, '.')
    plt.xlabel('SNR')
    plt.ylabel('recall')    
    plt.ylim(0,1)
    nUnits_above = np.sum(np.array(L_recall1) >= accuracy_thresh)
    plt.title('{} units > {} recall'.format(nUnits_above, accuracy_thresh))  
    
    ax=fig.add_subplot(1,3,3)
    ax.plot(L_snr, L_precision1, '.')
    plt.xlabel('SNR')
    plt.ylabel('precision')    
    plt.ylim(0,1)
    nUnits_above = np.sum(np.array(L_precision1) >= accuracy_thresh)
    plt.title('{} units > {} precision'.format(nUnits_above, accuracy_thresh))  
    
    plt.show()
# Out:
# KiloSort
# IronClust_static
# MountainSort4
