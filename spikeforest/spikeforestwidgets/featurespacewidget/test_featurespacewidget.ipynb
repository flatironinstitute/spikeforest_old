# %%
# %load_ext autoreload
# %autoreload 2
        
import spikeforestwidgets as SFW
from spikeforest import spikeextractors as se
import vdomr as vd

vd.config_jupyter()
# Out:
# JSProxyWidget(status='Not yet rendered')

# %%
from spikeforest import spikewidgets as sw

# %%
recording,sorting=se.example_datasets.toy_example1(duration=30,num_channels=4,samplerate=30000)

# %%
X=SFW.TimeseriesWidget(recording=recording)
display(X)
# Out:
# (4, 900000)
# length of b64: 19200028
# rendering timeserieswidget...
# <div id=SFTimeseriesWidget-343ead37-7e75-42f8-bc24-68e7329d8c4d><div id="SFTimeseriesWidget-343ead37-7e75-42f8-bc24-68e7329d8c4d"></div></div>

# %%
X=SFW.FeatureSpaceWidget(recording=recording)
display(X)
# Out:
# (4, 900000)
# length of b64: 19200028
# rendering featurespacewidget...
# <div id=SFFeatureSpaceWidget-ca56accd-5bb4-4595-9a85-66b1388df2c5><div id="SFFeatureSpaceWidget-ca56accd-5bb4-4595-9a85-66b1388df2c5"></div></div>

# %%
sw.FeatureSpaceWidget(sorting=sorting, recording=recording, max_num_spikes_per_unit=100,
                     unit_ids=[1,2]).plot()
# Out:
# (4, 100, 76)
